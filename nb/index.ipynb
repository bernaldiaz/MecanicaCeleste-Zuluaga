# %% [markdown]
# <p style="margin:3em"></p>
# <p style="text-align:center;font-size:3em;font-weight:bold">Mecánica Celeste</p>
# <p style="text-align:center;font-size:2em">Teoría, algoritmos y problemas</p>

# %% [markdown]
# ![Portada](./figures/portada.png)

# %% [markdown]
# <p style="text-align:center;font-size:2em;font-weight:bold">Jorge I. Zuluaga</p>
# <p style="text-align:center;font-size:1.2em">Profesor Titular de Física y Astronomía</p>
# <p style="text-align:center;font-size:1.2em">Instituto de Física, Facultad de Ciencias Exactas y Naturales</p>
# <p style="text-align:center;font-size:1.2em">Universidad de Antioquia</p>

# %% [markdown]
# ---

# %% [markdown]
# <p style="margin:1em"></p>
# <p style="text-align:center;font-size:2em;font-weight:bold">Tabla de Contenido</p>
# <p style="margin:1em"></p>

# %% [markdown]
# ## Índice de materias
# - [Prefacio](01.00.00.00.Prefacio.ipynb#prefacio). <b>{#prefacio}</b>
#    - [¿Otro libro de mecánica celeste?](01.00.00.00.Prefacio.ipynb#otro_libro). <b>{#otro_libro}</b>
#    - [Mecánica celeste y mecánica analítica](01.00.00.00.Prefacio.ipynb#celeste_analitica). <b>{#celeste_analitica}</b>
#    - [Mecánica celeste en la era de la información](01.00.00.00.Prefacio.ipynb#celeste_era_informacion). <b>{#celeste_era_informacion}</b>
#    - [Mecánica celeste en Python](01.00.00.00.Prefacio.ipynb#celeste_python). <b>{#celeste_python}</b>
#    - [Mecánica celeste con `SPICE`](01.00.00.00.Prefacio.ipynb#celeste_spice). <b>{#celeste_spice}</b>
#    - [¿Qué hace distinto a este libro?: un decálogo](01.00.00.00.Prefacio.ipynb#libro_distinto). <b>{#libro_distinto}</b>
# - [Agradecimientos](02.00.00.00.Agradecimientos.ipynb#agradecimientos). <b>{#agradecimientos}</b>
# - [Introducción](03.00.00.00.Introduccion.ipynb#introduccion). <b>{#introduccion}</b>
#    - [¿Cómo se organiza este libro?](03.00.00.00.Introduccion.ipynb#organizacion_libro). <b>{#organizacion_libro}</b>
#    - [¿Cómo usar este libro?](03.00.00.00.Introduccion.ipynb#como_usar_libro). <b>{#como_usar_libro}</b>
#    - [Mecánica celeste en *libretas*](03.00.00.00.Introduccion.ipynb#celeste_libretas). <b>{#celeste_libretas}</b>
#       - [Instalación de las libretas](03.00.00.00.Introduccion.ipynb#instalacion_libretas). <b>{#instalacion_libretas}</b>
#    - [Idioma y Notación](03.00.00.00.Introduccion.ipynb#idioma_notacion). <b>{#idioma_notacion}</b>
#       - [Palabras extranjeras y guía de pronunciación](03.00.00.00.Introduccion.ipynb#extranjerismos_pronunciacion). <b>{#extranjerismos_pronunciacion}</b>
#       - [Siglos y décadas](03.00.00.00.Introduccion.ipynb#siglos_decadas). <b>{#siglos_decadas}</b>
#       - [Notación matemática](03.00.00.00.Introduccion.ipynb#notacion). <b>{#notacion}</b>
#    - [Elementos no textuales](03.00.00.00.Introduccion.ipynb#elementos_no_textuales). <b>{#elementos_no_textuales}</b>
#       - [Cajas de texto](03.00.00.00.Introduccion.ipynb#cajas_texto). <b>{#cajas_texto}</b>
#       - [Algoritmos](03.00.00.00.Introduccion.ipynb#algoritmos). <b>{#algoritmos}</b>
#    - [Figuras interactivas y animaciones](03.00.00.00.Introduccion.ipynb#interactivas_animaciones). <b>{#interactivas_animaciones}</b>
#       - [Ejemplo de figura interactiva](03.00.00.00.Introduccion.ipynb#ejemplo_interactiva). <b>{#ejemplo_interactiva}</b>
#       - [Ejemplo de figura animada](03.00.00.00.Introduccion.ipynb#ejemplo_animada). <b>{#ejemplo_animada}</b>
# - [Fundamentos matemáticos](04.00.00.00.Fundamentos.ipynb#fundamentos). <b>{#fundamentos}</b>
#    - [Vectores y cálculo](04.01.00.00.Fundamentos.Calculo.ipynb#vectores_calculo). <b>{#vectores_calculo}</b>
#       - [Conjunto, tuplas y vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#conjuntos_tuplas_vectores). <b>{#conjuntos_tuplas_vectores}</b>
#       - [Sistemas de coordenadas](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#sistemas_coordenadas). <b>{#sistemas_coordenadas}</b>
#       - [Funciones](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones). <b>{#funciones}</b>
#       - [Derivadas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#derivadas). <b>{#derivadas}</b>
#       - [Funciones homogéneas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones_homogeneas). <b>{#funciones_homogeneas}</b>
#          - [Algoritmos para la derivada](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_derivada). <b>{#algoritmos_derivada}</b>
#       - [Integrales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales). <b>{#integrales}</b>
#       - [Integrales vectoriales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales_vectoriales). <b>{#integrales_vectoriales}</b>
#          - [Algoritmos para la integral](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_integral). <b>{#algoritmos_integral}</b>
#       - [Ecuaciones diferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#ecuaciones_diferenciales). <b>{#ecuaciones_diferenciales}</b>
#          - [Algoritmos para la solución de ODE](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#algoritmos_ode). <b>{#algoritmos_ode}</b>
#       - [Funcionales y cálculo de variaciones](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#funcionales_calculo_variaciones). <b>{#funcionales_calculo_variaciones}</b>
#          - [Algoritmos en el cálculo variacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#algoritmos_calculo_variacional). <b>{#algoritmos_calculo_variacional}</b>
#       - [Gráficos interactivos](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#graficos_interactivos_variacional). <b>{#graficos_interactivos_variacional}</b>
#       - [Series infinitas](04.01.05.00.Fundamentos.Calculo.Series.ipynb#series_infinitas). <b>{#series_infinitas}</b>
#          - [Series de potencias](04.01.05.00.Fundamentos.Calculo.Series.ipynb#series_potencias). <b>{#series_potencias}</b>
#          - [Otras series](04.01.05.00.Fundamentos.Calculo.Series.ipynb#otras_series). <b>{#otras_series}</b>
#          - [Series de Stumpff](04.01.05.00.Fundamentos.Calculo.Series.ipynb#series_stumpff). <b>{#series_stumpff}</b>
#          - [Series de Fourier](04.01.05.00.Fundamentos.Calculo.Series.ipynb#series_fourier). <b>{#series_fourier}</b>
#    - [Curvas cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas). <b>{#conicas}</b>
#       - [Definición geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_definicion). <b>{#conicas_definicion}</b>
#       - [Del nombre al álgebra](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_nombre_algebra). <b>{#conicas_nombre_algebra}</b>
#       - [Directriz de las cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_directriz). <b>{#conicas_directriz}</b>
#       - [Síntesis geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_sintesis_geometrica). <b>{#conicas_sintesis_geometrica}</b>
#       - [Descripción algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_algebra). <b>{#conicas_algebra}</b>
#       - [Ecuación respecto al centro](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_centro). <b>{#conicas_centro}</b>
#       - [Eje mayor y menor de la elipse](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ejes). <b>{#conicas_ejes}</b>
#          - [Elipse interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#elipse_interactiva). <b>{#elipse_interactiva}</b>
#       - [Parámetros de la hipérbola](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#subsubsec_conicas_hiperbola). <b>{#subsubsec_conicas_hiperbola}</b>
#          - [Hipérbola interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#hiperbola_interactiva). <b>{#hiperbola_interactiva}</b>
#       - [Rotación de las cónicas en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_rotacion_plano). <b>{#conicas_rotacion_plano}</b>
#       - [Ecuación general de las cónicas](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ecuacion_general). <b>{#conicas_ecuacion_general}</b>
#       - [Gráfico de una cónica rotada en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#grafico_conica_rotada_plano). <b>{#grafico_conica_rotada_plano}</b>
#       - [Síntesis algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_sintesis_algebraica). <b>{#conicas_sintesis_algebraica}</b>
#       - [Cónicas en coordenadas cilíndricas](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_cilindricas). <b>{#conicas_cilindricas}</b>
#       - [Anomalías](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_anomalias). <b>{#conicas_anomalias}</b>
#       - [Área de las cónicas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_conicas). <b>{#area_conicas}</b>
#          - [Área de un sector de elipse](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_elipse). <b>{#area_elipse}</b>
#          - [Área de un sector de hipérbola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_hiperbola). <b>{#area_hiperbola}</b>
#          - [Área de un sector de parábola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_parábola). <b>{#area_parábola}</b>
#       - [Cónicas en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#conicas_espacio). <b>{#conicas_espacio}</b>
#       - [Ángulos de Euler](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#angulos_euler). <b>{#angulos_euler}</b>
#       - [Matrices de rotación generales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#matrices_rotacion_generales). <b>{#matrices_rotacion_generales}</b>
#       - [Gráfico de una cónica rotada en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#grafico_conica_rotada_espacio). <b>{#grafico_conica_rotada_espacio}</b>
#       - [Elementos orbitales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#elementos_orbitales). <b>{#elementos_orbitales}</b>
#    - [Problemas seleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fundamentos_problemas). <b>{#fundamentos_problemas}</b>
# - [Mecánica newtoniana](05.00.00.00.Mecanica.ipynb#mecanica). <b>{#mecanica}</b>
#    - [Introducción](05.00.00.00.Mecanica.Introduccion.ipynb#mecanica_introduccion). <b>{#mecanica_introduccion}</b>
#    - [Cinemática](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#cinematica). <b>{#cinematica}</b>
#       - [Cantidades cinemáticas](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#cantidades_cinematicas). <b>{#cantidades_cinematicas}</b>
#       - [Sistemas de referencia](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#sistemas_referencia). <b>{#sistemas_referencia}</b>
#       - [La ecuación de movimiento (e.d.m.)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#ecuacion_movimiento). <b>{#ecuacion_movimiento}</b>
#       - [Integración de la e.d.m.](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#integracion_edm). <b>{#integracion_edm}</b>
#       - [Integración por cuadraturas](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#integracion_cuadraturas). <b>{#integracion_cuadraturas}</b>
#       - [Integración numérica de la e.d.m.](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#integracion_numerica_edm). <b>{#integracion_numerica_edm}</b>
#    - [Dinámica](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#dinamica). <b>{#dinamica}</b>
#       - [Cantidades dinámicas](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#cantidades_dinamicas). <b>{#cantidades_dinamicas}</b>
#       - [Partículas y fuerzas](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#particulas_fuerzas). <b>{#particulas_fuerzas}</b>
#       - [Sistemas de referencia inerciales](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#sistemas_referencia_inerciales). <b>{#sistemas_referencia_inerciales}</b>
#       - [Postulado de fuerzas](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_fuerzas). <b>{#postulado_fuerzas}</b>
#       - [Fuerzas conservativas y no conservativas](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fuerzas_conservativas). <b>{#fuerzas_conservativas}</b>
#       - [Energía mecánica](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#energia_mecanica). <b>{#energia_mecanica}</b>
#       - [¿Ley de inercia?](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#ley_inercia). <b>{#ley_inercia}</b>
#       - [Postulado de acción y reacción](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_accion_reaccion). <b>{#postulado_accion_reaccion}</b>
#       - [Postulado de gravitación universal](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_gravitacion). <b>{#postulado_gravitacion}</b>
#       - [La fuerza gravitacional de la Tierra, el Sol y la la Luna](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fuerza_luna). <b>{#fuerza_luna}</b>
#       - [El campo gravitacional](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#campo_gravitacional). <b>{#campo_gravitacional}</b>
#       - [Energía potencial gravitacional](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#energia_potencial_gravitacional). <b>{#energia_potencial_gravitacional}</b>
#       - [Masa y principio de equivalencia](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#masa_equivalencia). <b>{#masa_equivalencia}</b>
#    - [Sistemas de partículas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#sistemas_particulas). <b>{#sistemas_particulas}</b>
#       - [Fuerzas y centro de masa](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fuerzas_centro_masa). <b>{#fuerzas_centro_masa}</b>
#       - [Centro de masa de un sistema de dos partículas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#centro_masa). <b>{#centro_masa}</b>
#       - [Teoremas de conservación](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#teoremas_conservacion). <b>{#teoremas_conservacion}</b>
#       - [Dinámica referida al centro de masa](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#dinamica_centro_masa). <b>{#dinamica_centro_masa}</b>
#    - [Dinámica en sistemas de referencia no inerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#sistemas_no_inerciales). <b>{#sistemas_no_inerciales}</b>
#       - [Transformación entre sistemas de referencia](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#transformacion_sistemas_referencia). <b>{#transformacion_sistemas_referencia}</b>
#       - [Sistemas de referencia rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#sistemas_rotantes). <b>{#sistemas_rotantes}</b>
#       - [Adición de velocidades en sistemas rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#adicion_velocidades_rotantes). <b>{#adicion_velocidades_rotantes}</b>
#       - [Aceleraciones ficticias en sistemas rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#aceleraciones_ficticias_rotantes). <b>{#aceleraciones_ficticias_rotantes}</b>
#       - [Un ejemplo numérico](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb#ejemplo_numerico_rotante). <b>{#ejemplo_numerico_rotante}</b>
#    - [Problemas seleccionados](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb#mecanica_problemas). <b>{#mecanica_problemas}</b>

# %% [markdown]
# ## Índice de figuras
# - Figuras en [01.00.00.00.Prefacio](01.00.00.00.Prefacio.ipynb)
#    - [Figura 1.1](01.00.00.00.Prefacio.ipynb#fig:utlima_thule). Imagen procesada de Arrokoth, el objeto transneptuniano sobrevolado por la sonda New Horizons el 1 de enero 2019 (crédito: NASA/Johns Hopkins University Applied Physics Laboratory/Southwest Research Institute/Roman Tkachenko.). <b>{fig:utlima_thule}</b>
# - Figuras en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#    - [Figura 3.3](03.00.00.00.Introduccion.ipynb#fig:teorema_danelin). Ilustración esquemática del *teorema de Danelin*.. <b>{fig:teorema_danelin}</b>
#    - [Figura 3.4](03.00.00.00.Introduccion.ipynb#fig:kepler). Retrato de Johanes Kepler, copia de un original de 1610 de pintor desconocido y que se conserva en el monasterio Benedictino de Kremsmünster (Alemania).. <b>{fig:kepler}</b>
# - Figuras en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#    - [Figura 4.7](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:vectores). Definición geométrica de vector espacial y de sus operaciones básicas (suma, resta y multiplicación por un escalar). Aunque la resta de $. <b>{fig:vectores}</b>
#    - [Figura 4.8](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:coordenadas). Definción de los sistemas de coordenadas usadas en este texto. <b>{fig:coordenadas}</b>
# - Figuras en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#    - [Figura 4.10](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#fig:variacion_funcion). El área bajo una curva es un funcional, en tanto depende de la función que represente la curva, $f(t)$ o $f_0(t)$ Se conoce como una variación $. <b>{fig:variacion_funcion}</b>
# - Figuras en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#    - [Figura 4.15](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_definicion). Definición geométrica original de las *curvas cónicas*.. <b>{fig:conicas_definicion}</b>
#    - [Figura 4.16](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_apolonio). Definición con *áreas aplicadas* de las *curvas cónicas* y el origen de sus nombres.. <b>{fig:conicas_apolonio}</b>
#    - [Figura 4.19](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_directriz). Definición de las cónicas usando la recta directriz y el foco.. <b>{fig:conicas_directriz}</b>
# - Figuras en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#    - [Figura 4.20](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la elipse referidos al apside O, el foco F y el centro C: $a$ semieje mayor, $b$ semieje menor, $p$ *semilatus rectum*, $e$ excentricidad, $c$ distancia foco-centro.. <b>{fig:elipse}</b>
#    - [Figura 4.22](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la hipérbola referidos al apside O, el foco F y el vértice C: $a$ distancia al vértice (llamado con frecuencia también semieje mayor aunque en la hipérbola no hay tal), $. <b>{fig:elipse}</b>
# - Figuras en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#    - [Figura 4.26](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:conica_foco). Derivación de la ecuación de la cónica en coordenadas cilíndricas referidas al Foco.  En la figura el ángulo $f$ es la *anomalía verdadera*.. <b>{fig:conica_foco}</b>
#    - [Figura 4.29](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:anomalia_excentrica). Definición de la anomalía excéntrica $E$ y el método asociada a ella para determinar la posición de los puntos sobre una elipse.. <b>{fig:anomalia_excentrica}</b>
# - Figuras en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#    - [Figura 4.32](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#fig:conicas_area). Construcción geométrica usada aquí para deducir la relación entre las anomalías $f$, $E$ y $F$ y el área del sector de cónica (región sombreada).. <b>{fig:conicas_area}</b>
# - Figuras en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#    - [Figura 4.33](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#fig:angulos_euler). Secuencia de rotaciones que permiten pasar del sistema natural de ejes de la cónica $x-y-z$ a un sistema con una orientación arbitraria $x'''-y'''-z'''$. <b>{fig:angulos_euler}</b>
# - Figuras en [04.03.00.00.Fundamentos.ProblemasSeleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb)
#    - [Figura 4.37](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:elipse). Una elipse con algunos puntos resaltados.. <b>{fig:prob:elipse}</b>
#    - [Figura 4.38](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:latlon). Definición de elas coordenadas de latitud y longitud sobre la Tierra. <b>{fig:prob:latlon}</b>
# - Figuras en [05.01.01.00.Mecanica.Cinematica.Cantidades](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb)
#    - [Figura 5.39](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#fig:transformaciones_galileo). Construcción geométrica para deducir la regla de transformación de la posición $. <b>{fig:transformaciones_galileo}</b>
# - Figuras en [05.02.01.00.Mecanica.Dinamica.Postulados](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb)
#    - [Figura 5.43](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:principia). Fotografía de la copia persona de Newton de la primera edición de los *Principia*, incluyendo correcciones hechas a mano por el mismo Newton. Foto: Andrew Dunn, http://bit.ly/2WugALe.. <b>{fig:principia}</b>
#    - [Figura 5.44](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:accion_reaccion). Dos formas del postulado de acción y reacción: a la izquierda el postulado débil, en el que las fuerzas son iguales y de sentido contrario, pero no son paralelas a la línea que une las partículas; a la derecha el postulado fuerte en el que la acción y reacción actúan sobre la línea que une a las partículas.. <b>{fig:accion_reaccion}</b>
#    - [Figura 5.45](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:fuerza_gravitacional). Definición de los vectores de posición, vector relativo y vector de fuerza en el postulado de gravitación universal.. <b>{fig:fuerza_gravitacional}</b>
#    - [Figura 5.46](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:hooke). Robert Hooke (1635-1753). Crédito: Rita Greer (2004).. <b>{fig:hooke}</b>
#    - [Figura 5.47](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:stevin). El único retrato disponible de Simon Stevin (ca. 1548). Crédito: Colección Universidad de Leiden.. <b>{fig:stevin}</b>
# - Figuras en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#    - [Figura 5.50](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fig:centro_masa). Relación entre la posición del centro de masa $. <b>{fig:centro_masa}</b>
#    - [Figura 5.51](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fig:astronomia_nova). Primera página de la obra cumbre de Kepler *Astronomía Nova*.. <b>{fig:astronomia_nova}</b>
# - Figuras en [05.03.00.00.Mecanica.SistemasNoInerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb)
#    - [Figura 5.52](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:transformaciones_noinercial). Construcción geométrica para deducir la regla de transformación de la posición $. <b>{fig:transformaciones_noinercial}</b>
#    - [Figura 5.53](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:iss_microgravedad). Explicación de la experiencia de ingravidez en el interior de un vehículo espacial, en este caso un módulo de la Estación Espacial Internacional.  El módulo corresponde a un sistema de referencia no inercial con una aceleración $. <b>{fig:iss_microgravedad}</b>
#    - [Figura 5.54](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:rotacion_ejes). Construcción geométrica usada para calcular el cambio en la dirección de los vectores unitarios coordenados de un sistema de coordenadas cuando se produce una rotación alrededor de un eje arbitrario $. <b>{fig:rotacion_ejes}</b>
#    - [Figura 5.55](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:rotaciones_no_conmutativas). Las rotaciones, representadas aquí por $. <b>{fig:rotaciones_no_conmutativas}</b>
#    - [Figura 5.56](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:aceleraciones_ficticias). Explicación esquemática del origen y dirección de las aceleraciones centrífuga y de Coriolís.. <b>{fig:aceleraciones_ficticias}</b>
#    - [Figura 5.57](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:coriolis). Gaspard-Gustave Coriolis (1792-1843) en un retrato de 1841.  Coriolís tuvo la suerte de que una de las más importantes aceleraciones ficticias que se producen en sistemas en rotación, y que habían sido identificada y descritas antes por varios físicos desde Laplace hasta Riccioli, llevara finalmente su nombre.. <b>{fig:coriolis}</b>
# - Figuras en [05.03.00.00.Mecanica.ProblemasSeleccionados](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb)
#    - [Figura 5.62](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb#fig:prob:lanzamiento_proyectil). Geometría del lanzamiento de un proyectil desde la superficie de una Tierra en rotación.. <b>{fig:prob:lanzamiento_proyectil}</b>

# %% [markdown]
# ## Índice de ecuaciones
# - Ecuaciones en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#     - [Ec. (4.1)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Asuma_tuplas): suma_tuplas. <b>{eq:suma_tuplas}</b>
#     - [Ec. (4.2)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Ak_tupla): k_tupla. <b>{eq:k_tupla}</b>
#     - [Ec. (4.3)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Avectores_en_base): vectores_en_base. <b>{eq:vectores_en_base}</b>
#     - [Ec. (4.4)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Adelta_kroenecker): delta_kroenecker. <b>{eq:delta_kroenecker}</b>
#     - [Ec. (4.5)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Abase_mano_derecha): base_mano_derecha. <b>{eq:base_mano_derecha}</b>
#     - [Ec. (4.6)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Alevi_civita): levi_civita. <b>{eq:levi_civita}</b>
#     - [Ec. (4.7)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz): producto_cruz. <b>{eq:producto_cruz}</b>
#     - [Ec. (4.8)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz_determinante): producto_cruz_determinante. <b>{eq:producto_cruz_determinante}</b>
#     - [Ec. (4.9)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_escalar): triple_producto_escalar. <b>{eq:triple_producto_escalar}</b>
#     - [Ec. (4.10)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_vectorial): triple_producto_vectorial. <b>{eq:triple_producto_vectorial}</b>
#     - [Ec. (4.11)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aconjunto_mano_derecha): conjunto_mano_derecha. <b>{eq:conjunto_mano_derecha}</b>
#     - [Ec. (4.12)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Acilindricas_a_cartesianas): cilindricas_a_cartesianas. <b>{eq:cilindricas_a_cartesianas}</b>
#     - [Ec. (4.13)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_cilindricas): unitarios_cilindricas. <b>{eq:unitarios_cilindricas}</b>
#     - [Ec. (4.14)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aesfericas_a_cartesianas): esfericas_a_cartesianas. <b>{eq:esfericas_a_cartesianas}</b>
#     - [Ec. (4.15)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_esfericas): unitarios_esfericas. <b>{eq:unitarios_esfericas}</b>
# - Ecuaciones en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Ec. (4.16)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aderivada_definicion): derivada_definicion. <b>{eq:derivada_definicion}</b>
#     - [Ec. (4.17)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_general): regla_cadena_general. <b>{eq:regla_cadena_general}</b>
#     - [Ec. (4.18)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cartesianas): gradiente_cartesianas. <b>{eq:gradiente_cartesianas}</b>
#     - [Ec. (4.19)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cilindricas): gradiente_cilindricas. <b>{eq:gradiente_cilindricas}</b>
#     - [Ec. (4.20)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_esfericas): gradiente_esfericas. <b>{eq:gradiente_esfericas}</b>
#     - [Ec. (4.21)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_multivariables): regla_cadena_multivariables. <b>{eq:regla_cadena_multivariables}</b>
#     - [Ec. (4.22)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Ateorema_fundamental_calculo): teorema_fundamental_calculo. <b>{eq:teorema_fundamental_calculo}</b>
# - Ecuaciones en [04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb)
#     - [Ec. (4.23)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_antiderivada): ecuacion_diferencial_antiderivada. <b>{eq:ecuacion_diferencial_antiderivada}</b>
#     - [Ec. (4.24)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple): ecuacion_diferencial_simple. <b>{eq:ecuacion_diferencial_simple}</b>
#     - [Ec. (4.25)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_reducida): ecuacion_diferencial_simple_reducida. <b>{eq:ecuacion_diferencial_simple_reducida}</b>
#     - [Ec. (4.26)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuaciones_reducidas): ecuaciones_reducidas. <b>{eq:ecuaciones_reducidas}</b>
#     - [Ec. (4.27)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_identificacion): ecuacion_diferencial_simple_identificacion. <b>{eq:ecuacion_diferencial_simple_identificacion}</b>
# - Ecuaciones en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Ec. (4.28)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Avariacion): variacion. <b>{eq:variacion}</b>
#     - [Ec. (4.29)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Alongitud_curva): longitud_curva. <b>{eq:longitud_curva}</b>
#     - [Ec. (4.30)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Afuncional_integral): funcional_integral. <b>{eq:funcional_integral}</b>
#     - [Ec. (4.31)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3AdIdepsilon): dIdepsilon. <b>{eq:dIdepsilon}</b>
#     - [Ec. (4.32)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_integral_variaciones): ecuacion_integral_variaciones. <b>{eq:ecuacion_integral_variaciones}</b>
#     - [Ec. (4.33)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_euler_lagrange): ecuacion_euler_lagrange. <b>{eq:ecuacion_euler_lagrange}</b>
# - Ecuaciones en [04.01.05.00.Fundamentos.Calculo.Series](04.01.05.00.Fundamentos.Calculo.Series.ipynb)
#     - [Ec. (4.34)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aserie_potencias_limite): serie_potencias_limite. <b>{eq:serie_potencias_limite}</b>
#     - [Ec. (4.35)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aexp_taylor): exp_taylor. <b>{eq:exp_taylor}</b>
#     - [Ec. (4.36)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aserie_taylor): serie_taylor. <b>{eq:serie_taylor}</b>
#     - [Ec. (4.37)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Asin_taylor): sin_taylor. <b>{eq:sin_taylor}</b>
#     - [Ec. (4.38)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Acos_taylor): cos_taylor. <b>{eq:cos_taylor}</b>
#     - [Ec. (4.39)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Asinh_taylor): sinh_taylor. <b>{eq:sinh_taylor}</b>
#     - [Ec. (4.40)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Acosh_taylor): cosh_taylor. <b>{eq:cosh_taylor}</b>
#     - [Ec. (4.41)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aexp_taylor_general): exp_taylor_general. <b>{eq:exp_taylor_general}</b>
#     - [Ec. (4.42)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aserie_geometrica): serie_geometrica. <b>{eq:serie_geometrica}</b>
#     - [Ec. (4.43)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aserie_binomio): serie_binomio. <b>{eq:serie_binomio}</b>
#     - [Ec. (4.44)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Astumpff_recurrencia): stumpff_recurrencia. <b>{eq:stumpff_recurrencia}</b>
#     - [Ec. (4.45)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Astumpff_derivadas_recurrencia): stumpff_derivadas_recurrencia. <b>{eq:stumpff_derivadas_recurrencia}</b>
#     - [Ec. (4.46)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Ac0_trigo): c0_trigo. <b>{eq:c0_trigo}</b>
#     - [Ec. (4.47)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Ac1_trigo): c1_trigo. <b>{eq:c1_trigo}</b>
#     - [Ec. (4.48)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Astumpff_iteracion): stumpff_iteracion. <b>{eq:stumpff_iteracion}</b>
#     - [Ec. (4.49)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Astumpff_iteracion_error): stumpff_iteracion_error. <b>{eq:stumpff_iteracion_error}</b>
#     - [Ec. (4.50)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3AAn_serie_funciones): An_serie_funciones. <b>{eq:An_serie_funciones}</b>
#     - [Ec. (4.51)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3Aserie_fourier): serie_fourier. <b>{eq:serie_fourier}</b>
#     - [Ec. (4.52)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3AA0_fourier): A0_fourier. <b>{eq:A0_fourier}</b>
#     - [Ec. (4.53)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3AAn_fourier): An_fourier. <b>{eq:An_fourier}</b>
#     - [Ec. (4.54)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#mjx-eqn-eq%3ABn_fourier): Bn_fourier. <b>{eq:Bn_fourier}</b>
# - Ecuaciones en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#     - [Ec. (4.55)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_apside): ecuacion_apside. <b>{eq:ecuacion_apside}</b>
#     - [Ec. (4.56)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon): conica_razon. <b>{eq:conica_razon}</b>
#     - [Ec. (4.57)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon_cartesianas): conica_razon_cartesianas. <b>{eq:conica_razon_cartesianas}</b>
#     - [Ec. (4.58)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz): ecuacion_directriz. <b>{eq:ecuacion_directriz}</b>
#     - [Ec. (4.59)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aalpha): alpha. <b>{eq:alpha}</b>
#     - [Ec. (4.60)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aq): q. <b>{eq:q}</b>
#     - [Ec. (4.61)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz_trasladada): ecuacion_directriz_trasladada. <b>{eq:ecuacion_directriz_trasladada}</b>
#     - [Ec. (4.62)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aeta_apolonio): eta_apolonio. <b>{eq:eta_apolonio}</b>
# - Ecuaciones en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Ec. (4.63)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_apside_pe): ecuacion_apside_pe. <b>{eq:ecuacion_apside_pe}</b>
#     - [Ec. (4.64)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Atraslacion_centro): traslacion_centro. <b>{eq:traslacion_centro}</b>
#     - [Ec. (4.65)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemayor): semiejemayor. <b>{eq:semiejemayor}</b>
#     - [Ec. (4.66)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro): ecuacion_centro. <b>{eq:ecuacion_centro}</b>
#     - [Ec. (4.67)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemenor): semiejemenor. <b>{eq:semiejemenor}</b>
#     - [Ec. (4.68)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro_hiperbola): ecuacion_centro_hiperbola. <b>{eq:ecuacion_centro_hiperbola}</b>
#     - [Ec. (4.69)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Abeta): beta. <b>{eq:beta}</b>
#     - [Ec. (4.70)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Acos_psi): cos_psi. <b>{eq:cos_psi}</b>
#     - [Ec. (4.71)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d): rotacion2d. <b>{eq:rotacion2d}</b>
#     - [Ec. (4.72)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_matricial): rotacion2d_matricial. <b>{eq:rotacion2d_matricial}</b>
#     - [Ec. (4.73)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Amatriz_rotacion2d): matriz_rotacion2d. <b>{eq:matriz_rotacion2d}</b>
#     - [Ec. (4.74)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ainversa_matriz_rotacion): inversa_matriz_rotacion. <b>{eq:inversa_matriz_rotacion}</b>
#     - [Ec. (4.75)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa_matricial): rotacion2d_inversa_matricial. <b>{eq:rotacion2d_inversa_matricial}</b>
#     - [Ec. (4.76)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa): rotacion2d_inversa. <b>{eq:rotacion2d_inversa}</b>
#     - [Ec. (4.77)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_conica_trasladada_rotada): ecuacion_conica_trasladada_rotada. <b>{eq:ecuacion_conica_trasladada_rotada}</b>
#     - [Ec. (4.78)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general): ecuacion_general. <b>{eq:ecuacion_general}</b>
#     - [Ec. (4.79)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general_coeficientes): ecuacion_general_coeficientes. <b>{eq:ecuacion_general_coeficientes}</b>
#     - [Ec. (4.80)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aeta_ecuacion_general): eta_ecuacion_general. <b>{eq:eta_ecuacion_general}</b>
#     - [Ec. (4.81)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ateta_ecuacion_general): teta_ecuacion_general. <b>{eq:teta_ecuacion_general}</b>
#     - [Ec. (4.82)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aty_ecuacion_general): ty_ecuacion_general. <b>{eq:ty_ecuacion_general}</b>
# - Ecuaciones en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Ec. (4.83)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aecuacion_foco): ecuacion_foco. <b>{eq:ecuacion_foco}</b>
#     - [Ec. (4.84)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_f): conica_parametricas_f. <b>{eq:conica_parametricas_f}</b>
#     - [Ec. (4.85)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_ecuacion_cilindricas): conica_ecuacion_cilindricas. <b>{eq:conica_ecuacion_cilindricas}</b>
#     - [Ec. (4.86)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_E): conica_parametricas_E. <b>{eq:conica_parametricas_E}</b>
#     - [Ec. (4.87)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_anomalia_excentrica): conica_anomalia_excentrica. <b>{eq:conica_anomalia_excentrica}</b>
#     - [Ec. (4.88)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3AfE): fE. <b>{eq:fE}</b>
#     - [Ec. (4.89)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Ahiperbola_parametrica_F): hiperbola_parametrica_F. <b>{eq:hiperbola_parametrica_F}</b>
# - Ecuaciones en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#     - [Ec. (4.90)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector): area_sector. <b>{eq:area_sector}</b>
#     - [Ec. (4.91)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PFQ): A_PFQ. <b>{eq:A_PFQ}</b>
#     - [Ec. (4.92)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PQO): A_PQO. <b>{eq:A_PQO}</b>
#     - [Ec. (4.93)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_RQO): A_RQO. <b>{eq:A_RQO}</b>
#     - [Ec. (4.94)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_elipse): area_sector_elipse. <b>{eq:area_sector_elipse}</b>
#     - [Ec. (4.95)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_elipse): area_elipse. <b>{eq:area_elipse}</b>
#     - [Ec. (4.96)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_hiperbola): area_sector_hiperbola. <b>{eq:area_sector_hiperbola}</b>
#     - [Ec. (4.97)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_parabola): area_sector_parabola. <b>{eq:area_sector_parabola}</b>
# - Ecuaciones en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Ec. (4.98)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_R): rotacion3d_observador_R. <b>{eq:rotacion3d_observador_R}</b>
#     - [Ec. (4.99)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_M): rotacion3d_observador_M. <b>{eq:rotacion3d_observador_M}</b>
#     - [Ec. (4.100)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_definicion): matrizM_definicion. <b>{eq:matrizM_definicion}</b>
#     - [Ec. (4.101)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita): matrizM_explicita. <b>{eq:matrizM_explicita}</b>
#     - [Ec. (4.102)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita_transpuesta): matrizM_explicita_transpuesta. <b>{eq:matrizM_explicita_transpuesta}</b>
#     - [Ec. (4.103)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_R): rotacion3d_natural_R. <b>{eq:rotacion3d_natural_R}</b>
#     - [Ec. (4.104)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_M): rotacion3d_natural_M. <b>{eq:rotacion3d_natural_M}</b>
#     - [Ec. (4.105)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Aelementos_estado_f): elementos_estado_f. <b>{eq:elementos_estado_f}</b>
# - Ecuaciones en [05.01.01.00.Mecanica.Cinematica.Cantidades](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb)
#     - [Ec. (5.106)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aa_cilindricas): a_cilindricas. <b>{eq:a_cilindricas}</b>
#     - [Ec. (5.107)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aa_esfericas): a_esfericas. <b>{eq:a_esfericas}</b>
#     - [Ec. (5.108)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Atransformaciones_galileo): transformaciones_galileo. <b>{eq:transformaciones_galileo}</b>
#     - [Ec. (5.109)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aley_adicion_velocidades): ley_adicion_velocidades. <b>{eq:ley_adicion_velocidades}</b>
#     - [Ec. (5.110)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aley_adicion_aceleraciones): ley_adicion_aceleraciones. <b>{eq:ley_adicion_aceleraciones}</b>
# - Ecuaciones en [05.01.02.00.Mecanica.Cinematica.SolucionEdM](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb)
#     - [Ec. (5.111)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm): edm. <b>{eq:edm}</b>
#     - [Ec. (5.112)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_primer_orden): edm_primer_orden. <b>{eq:edm_primer_orden}</b>
#     - [Ec. (5.113)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_escalar): edm_escalar. <b>{eq:edm_escalar}</b>
#     - [Ec. (5.114)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_primer_orden_escalar): edm_primer_orden_escalar. <b>{eq:edm_primer_orden_escalar}</b>
#     - [Ec. (5.115)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_estado): edm_estado. <b>{eq:edm_estado}</b>
#     - [Ec. (5.116)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_ejemplo1): edm_ejemplo1. <b>{eq:edm_ejemplo1}</b>
#     - [Ec. (5.117)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_ejemplo1_cuadratura): edm_ejemplo1_cuadratura. <b>{eq:edm_ejemplo1_cuadratura}</b>
#     - [Ec. (5.118)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3AIx_ejemplo1): Ix_ejemplo1. <b>{eq:Ix_ejemplo1}</b>
#     - [Ec. (5.119)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3AIx_ejemplo2): Ix_ejemplo2. <b>{eq:Ix_ejemplo2}</b>
#     - [Ec. (5.120)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aconstantes_ejemplo1): constantes_ejemplo1. <b>{eq:constantes_ejemplo1}</b>
#     - [Ec. (5.121)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Asolucion_ejemplo1): solucion_ejemplo1. <b>{eq:solucion_ejemplo1}</b>
# - Ecuaciones en [05.01.03.00.Mecanica.Cinematica.SolucionNumerica](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb)
#     - [Ec. (5.122)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Aedm_ecuaciones_reducidas): edm_ecuaciones_reducidas. <b>{eq:edm_ecuaciones_reducidas}</b>
#     - [Ec. (5.123)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Avariables_auxiliares_edm): variables_auxiliares_edm. <b>{eq:variables_auxiliares_edm}</b>
#     - [Ec. (5.124)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Aedm_reducidas_particula): edm_reducidas_particula. <b>{eq:edm_reducidas_particula}</b>
# - Ecuaciones en [05.02.01.00.Mecanica.Dinamica.Postulados](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb)
#     - [Ec. (5.125)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aedm_fuerzas_aplicadas): edm_fuerzas_aplicadas. <b>{eq:edm_fuerzas_aplicadas}</b>
#     - [Ec. (5.126)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aedm_fuerzas_resultantes): edm_fuerzas_resultantes. <b>{eq:edm_fuerzas_resultantes}</b>
#     - [Ec. (5.127)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acirculacion_nula): circulacion_nula. <b>{eq:circulacion_nula}</b>
#     - [Ec. (5.128)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuncion_energia_potencial): funcion_energia_potencial. <b>{eq:funcion_energia_potencial}</b>
#     - [Ec. (5.129)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3AdeltaU_deltaK): deltaU_deltaK. <b>{eq:deltaU_deltaK}</b>
#     - [Ec. (5.130)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_gravitacional): fuerza_gravitacional. <b>{eq:fuerza_gravitacional}</b>
#     - [Ec. (5.131)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_M_m): fuerza_M_m. <b>{eq:fuerza_M_m}</b>
#     - [Ec. (5.132)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acampo_gravitacional): campo_gravitacional. <b>{eq:campo_gravitacional}</b>
#     - [Ec. (5.133)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_campo_gravitacional): fuerza_campo_gravitacional. <b>{eq:fuerza_campo_gravitacional}</b>
#     - [Ec. (5.134)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aenergia_potencial_gravitacional): energia_potencial_gravitacional. <b>{eq:energia_potencial_gravitacional}</b>
#     - [Ec. (5.135)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acampo_gravitacional): campo_gravitacional. <b>{eq:campo_gravitacional}</b>
#     - [Ec. (5.136)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aenergia_fuerza_campo_gravitacional): energia_fuerza_campo_gravitacional. <b>{eq:energia_fuerza_campo_gravitacional}</b>
#     - [Ec. (5.137)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Apotencial_campo_gravitacional): potencial_campo_gravitacional. <b>{eq:potencial_campo_gravitacional}</b>
#     - [Ec. (5.138)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Arazon_masa_gravitacional_masa_inercial): razon_masa_gravitacional_masa_inercial. <b>{eq:razon_masa_gravitacional_masa_inercial}</b>
# - Ecuaciones en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#     - [Ec. (5.139)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aedm_sistema_particulas): edm_sistema_particulas. <b>{eq:edm_sistema_particulas}</b>
#     - [Ec. (5.140)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Acentro_masa): centro_masa. <b>{eq:centro_masa}</b>
#     - [Ec. (5.141)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aedm_sistema): edm_sistema. <b>{eq:edm_sistema}</b>
#     - [Ec. (5.142)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Adistancia_centro_masa): distancia_centro_masa. <b>{eq:distancia_centro_masa}</b>
#     - [Ec. (5.143)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Atorca_sistema): torca_sistema. <b>{eq:torca_sistema}</b>
#     - [Ec. (5.144)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AdLdt_sistema_torca): dLdt_sistema_torca. <b>{eq:dLdt_sistema_torca}</b>
#     - [Ec. (5.145)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Atorque_sistema): torque_sistema. <b>{eq:torque_sistema}</b>
#     - [Ec. (5.146)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aestado_CM): estado_CM. <b>{eq:estado_CM}</b>
#     - [Ec. (5.147)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AL_CM_interno): L_CM_interno. <b>{eq:L_CM_interno}</b>
#     - [Ec. (5.148)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AK_CM_interno): K_CM_interno. <b>{eq:K_CM_interno}</b>
# - Ecuaciones en [05.03.00.00.Mecanica.SistemasNoInerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb)
#     - [Ec. (5.149)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Atransformaciones_galileo): transformaciones_galileo. <b>{eq:transformaciones_galileo}</b>
#     - [Ec. (5.150)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Atransformaciones_acelerado): transformaciones_acelerado. <b>{eq:transformaciones_acelerado}</b>
#     - [Ec. (5.151)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Av_no_inercial): v_no_inercial. <b>{eq:v_no_inercial}</b>
#     - [Ec. (5.152)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Ap_no_inercial): p_no_inercial. <b>{eq:p_no_inercial}</b>
#     - [Ec. (5.153)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aa_no_inercial): a_no_inercial. <b>{eq:a_no_inercial}</b>
#     - [Ec. (5.154)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AF_no_inercial): F_no_inercial. <b>{eq:F_no_inercial}</b>
#     - [Ec. (5.155)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AF_aplicada_no_inercial): F_aplicada_no_inercial. <b>{eq:F_aplicada_no_inercial}</b>
#     - [Ec. (5.156)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AA_noinercial): A_noinercial. <b>{eq:A_noinercial}</b>
#     - [Ec. (5.157)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aderivada_vector_rotacion_explicita): derivada_vector_rotacion_explicita. <b>{eq:derivada_vector_rotacion_explicita}</b>
#     - [Ec. (5.158)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aderivada_vector_rotacion): derivada_vector_rotacion. <b>{eq:derivada_vector_rotacion}</b>
#     - [Ec. (5.159)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aomega_times_A): omega_times_A. <b>{eq:omega_times_A}</b>
#     - [Ec. (5.160)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aadicion_velocidades_rotante): adicion_velocidades_rotante. <b>{eq:adicion_velocidades_rotante}</b>
#     - [Ec. (5.161)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aley_adicion_aceleraciones): ley_adicion_aceleraciones. <b>{eq:ley_adicion_aceleraciones}</b>

# %% [markdown]
# ## Índice de códigos
# - Código en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#     - [Código (3.1)](03.00.00.00.Introduccion.ipynb#code:rutina_discriminante): rutina_discriminante. <b>{code:rutina_discriminante}</b>
#     - [Código (3.2)](03.00.00.00.Introduccion.ipynb#code:raiz_polinomio): raiz_polinomio. <b>{code:raiz_polinomio}</b>
#     - [Código (3.3)](03.00.00.00.Introduccion.ipynb#code:plot_sin): plot_sin. <b>{code:plot_sin}</b>
# - Código en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Código (4.4)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:rutina_potencial): rutina_potencial. <b>{code:rutina_potencial}</b>
#     - [Código (4.5)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:funcion_lambda): funcion_lambda. <b>{code:funcion_lambda}</b>
# - Código en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Código (4.6)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:funcional_integral): funcional_integral. <b>{code:funcional_integral}</b>
#     - [Código (4.7)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:minimiza_arco): minimiza_arco. <b>{code:minimiza_arco}</b>
# - Código en [04.01.05.00.Fundamentos.Calculo.Series](04.01.05.00.Fundamentos.Calculo.Series.ipynb)
#     - [Código (4.8)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#code:exp_negativo): exp_negativo. <b>{code:exp_negativo}</b>
#     - [Código (4.9)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#code:exp_positivo): exp_positivo. <b>{code:exp_positivo}</b>
#     - [Código (4.10)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#code:exp_taylor): exp_taylor. <b>{code:exp_taylor}</b>
#     - [Código (4.11)](04.01.05.00.Fundamentos.Calculo.Series.ipynb#code:coeficientes_fourier): coeficientes_fourier. <b>{code:coeficientes_fourier}</b>
# - Código en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Código (4.12)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:spice_rotate): spice_rotate. <b>{code:spice_rotate}</b>
#     - [Código (4.13)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:rota_puntos): rota_puntos. <b>{code:rota_puntos}</b>
#     - [Código (4.14)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:polinomio_segundo_grado): polinomio_segundo_grado. <b>{code:polinomio_segundo_grado}</b>
# - Código en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Código (4.15)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:conica_dibujo): conica_dibujo. <b>{code:conica_dibujo}</b>
#     - [Código (4.16)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:puntos_conica): puntos_conica. <b>{code:puntos_conica}</b>
# - Código en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Código (4.17)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_explicito): calculo_M_explicito. <b>{code:calculo_M_explicito}</b>
#     - [Código (4.18)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_general): calculo_M_general. <b>{code:calculo_M_general}</b>
#     - [Código (4.19)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:conica_de_elementos): conica_de_elementos. <b>{code:conica_de_elementos}</b>
# - Código en [05.01.03.00.Mecanica.Cinematica.SolucionNumerica](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb)
#     - [Código (5.20)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:edm_ejemplo1): edm_ejemplo1. <b>{code:edm_ejemplo1}</b>
#     - [Código (5.21)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:ejemplo1_grafico_solucion): ejemplo1_grafico_solucion. <b>{code:ejemplo1_grafico_solucion}</b>
#     - [Código (5.22)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:compara_numerica_analitica): compara_numerica_analitica. <b>{code:compara_numerica_analitica}</b>
#     - [Código (5.23)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:solucion_numerica_ejemplo2): solucion_numerica_ejemplo2. <b>{code:solucion_numerica_ejemplo2}</b>
# - Código en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#     - [Código (5.24)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:random_particles): random_particles. <b>{code:random_particles}</b>
#     - [Código (5.25)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:centro_masa): centro_masa. <b>{code:centro_masa}</b>
#     - [Código (5.26)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:grafico_sistema_ejemplo): grafico_sistema_ejemplo. <b>{code:grafico_sistema_ejemplo}</b>
#     - [Código (5.27)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:L_sistema_ejemplo): L_sistema_ejemplo. <b>{code:L_sistema_ejemplo}</b>
#     - [Código (5.28)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:K_sistema_ejemplo): K_sistema_ejemplo. <b>{code:K_sistema_ejemplo}</b>
# - Código en [05.03.01.00.Mecanica.SistemasNoInerciales.Numerico](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb)
#     - [Código (5.29)](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb#code:plot_rotating_frame): plot_rotating_frame. <b>{code:plot_rotating_frame}</b>
