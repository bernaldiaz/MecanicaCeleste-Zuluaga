# %% [markdown]
# <p style="margin:3em"></p>
# <p style="text-align:center;font-size:3em;font-weight:bold">Mecánica Celeste</p>
# <p style="text-align:center;font-size:2em">Teoría, algoritmos y problemas</p>

# %% [markdown]
# ![Portada](./figures/portada.png)

# %% [markdown]
# <p style="text-align:center;font-size:2em;font-weight:bold">Jorge I. Zuluaga</p>
# <p style="text-align:center;font-size:1.2em">Profesor Titular de Física y Astronomía</p>
# <p style="text-align:center;font-size:1.2em">Instituto de Física, Facultad de Ciencias Exactas y Naturales</p>
# <p style="text-align:center;font-size:1.2em">Universidad de Antioquia</p>

# %% [markdown]
# ---

# %% [markdown]
# <p style="margin:1em"></p>
# <p style="text-align:center;font-size:2em;font-weight:bold">Tabla de Contenido</p>
# <p style="margin:1em"></p>

# %% [markdown]
# ## Índice de materias
# - [Prefacio](01.00.00.00.Prefacio.ipynb#prefacio).
#    - [¿Otro libro de mecánica celeste?](01.00.00.00.Prefacio.ipynb#otro_libro).
#    - [Mecánica celeste y mecánica analítica](01.00.00.00.Prefacio.ipynb#celeste_analitica).
#    - [Mecánica celeste en la era de la información](01.00.00.00.Prefacio.ipynb#celeste_era_informacion).
#    - [Mecánica celeste en Python](01.00.00.00.Prefacio.ipynb#celeste_python).
#    - [Mecánica celeste con `SPICE`](01.00.00.00.Prefacio.ipynb#celeste_spice).
#    - [¿Qué hace distinto a este libro?: un decálogo](01.00.00.00.Prefacio.ipynb#libro_distinto).
# - [Agradecimientos](02.00.00.00.Agradecimientos.ipynb#agradecimientos).
# - [Introducción](03.00.00.00.Introduccion.ipynb#introduccion).
#    - [¿Cómo se organiza este libro?](03.00.00.00.Introduccion.ipynb#organizacion_libro).
#    - [¿Cómo usar este libro?](03.00.00.00.Introduccion.ipynb#como_usar_libro).
#    - [Mecánica celeste en *libretas*](03.00.00.00.Introduccion.ipynb#celeste_libretas).
#       - [Instalación de las libretas](03.00.00.00.Introduccion.ipynb#instalacion_libretas).
#    - [Idioma y Notación](03.00.00.00.Introduccion.ipynb#idioma_notacion).
#       - [Palabras extranjeras y guía de pronunciación](03.00.00.00.Introduccion.ipynb#extranjerismos_pronunciacion).
#       - [Siglos y décadas](03.00.00.00.Introduccion.ipynb#siglos_decadas).
#       - [Notación matemática](03.00.00.00.Introduccion.ipynb#notacion).
#    - [Elementos no textuales](03.00.00.00.Introduccion.ipynb#elementos_no_textuales).
#       - [Cajas de texto](03.00.00.00.Introduccion.ipynb#cajas_texto).
#       - [Algoritmos](03.00.00.00.Introduccion.ipynb#algoritmos).
#    - [Figuras interactivas y animaciones](03.00.00.00.Introduccion.ipynb#interactivas_animaciones).
#       - [Ejemplo de figura interactiva](03.00.00.00.Introduccion.ipynb#ejemplo_interactiva).
#       - [Ejemplo de figura animada](03.00.00.00.Introduccion.ipynb#ejemplo_animada).
# - [Fundamentos matemáticos](04.00.00.00.Fundamentos.ipynb#fundamentos).
#    - [Vectores y cálculo](04.01.00.00.Fundamentos.Calculo.ipynb#vectores_calculo).
#       - [Conjunto, tuplas y vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#conjuntos_tuplas_vectores).
#       - [Sistemas de coordenadas](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#sistemas_coordenadas).
#       - [Funciones](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones).
#       - [Derivadas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#derivadas).
#       - [Funciones homogéneas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones_homogeneas).
#          - [Algoritmos para la derivada](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_derivada).
#       - [Integrales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales).
#       - [Integrales vectoriales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales_vectoriales).
#          - [Algoritmos para la integral](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_integral).
#       - [Ecuaciones diferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#ecuaciones_diferenciales).
#          - [Algoritmos para la solución de ODE](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#algoritmos_ode).
#       - [Funcionales y cálculo de variaciones](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#funcionales_calculo_variaciones).
#          - [Algoritmos en el cálculo variacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#algoritmos_calculo_variacional).
#       - [Gráficos interactivos](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#graficos_interactivos_variacional).
#    - [Curvas cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas).
#       - [Definición geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_definicion).
#       - [Del nombre al álgebra](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_nombre_algebra).
#       - [Directriz de las cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_directriz).
#       - [Síntesis geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_sintesis_geometrica).
#       - [Descripción algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_algebra).
#       - [Ecuación respecto al centro](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_centro).
#       - [Eje mayor y menor de la elipse](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ejes).
#          - [Elipse interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#elipse_interactiva).
#       - [Parámetros de la hipérbola](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#subsubsec_conicas_hiperbola).
#          - [Hipérbola interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#hiperbola_interactiva).
#       - [Rotación de las cónicas en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_rotacion_plano).
#       - [Ecuación general de las cónicas](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ecuacion_general).
#       - [Gráfico de una cónica rotada en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#grafico_conica_rotada_plano).
#       - [Síntesis algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_sintesis_algebraica).
#       - [Cónicas en coordenadas cilíndricas](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_cilindricas).
#       - [Anomalías](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_anomalias).
#       - [Área de las cónicas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_conicas).
#          - [Área de un sector de elipse](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_elipse).
#          - [Área de un sector de hipérbola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_hiperbola).
#          - [Área de un sector de parábola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_parábola).
#       - [Cónicas en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#conicas_espacio).
#       - [Ángulos de Euler](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#angulos_euler).
#       - [Matrices de rotación generales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#matrices_rotacion_generales).
#       - [Gráfico de una cónica rotada en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#grafico_conica_rotada_espacio).
#       - [Elementos orbitales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#elementos_orbitales).
#    - [Problemas seleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fundamentos_problemas).

# %% [markdown]
# ## Índice de figuras
# - Figuras en [01.00.00.00.Prefacio](01.00.00.00.Prefacio.ipynb)
#    - [Figura 1.1](01.00.00.00.Prefacio.ipynb#fig:utlima_thule). Imagen procesada de Arrokoth, el objeto transneptuniano sobrevolado por la sonda New Horizons el 1 de enero 2019 (crédito: NASA/Johns Hopkins University Applied Physics Laboratory/Southwest Research Institute/Roman Tkachenko.).
# - Figuras en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#    - [Figura 3.3](03.00.00.00.Introduccion.ipynb#fig:teorema_danelin). Ilustración esquemática del *teorema de Danelin*..
#    - [Figura 3.4](03.00.00.00.Introduccion.ipynb#fig:kepler). Retrato de Johanes Kepler, copia de un original de 1610 de pintor desconocido y que se conserva en el monasterio Benedictino de Kremsmünster (Alemania)..
# - Figuras en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#    - [Figura 4.7](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:vectores). Definición geométrica de vector espacial y de sus operaciones básicas (suma, resta y multiplicación por un escalar). Aunque la resta de $.
#    - [Figura 4.8](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:coordenadas). Definción de los sistemas de coordenadas usadas en este texto.
# - Figuras en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#    - [Figura 4.10](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#fig:variacion_funcion). El área bajo una curva es un funcional, en tanto depende de la función que represente la curva, $f(t)$ o $f_0(t)$ Se conoce como una variación $.
# - Figuras en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#    - [Figura 4.13](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_definicion). Definición geométrica original de las *curvas cónicas*..
#    - [Figura 4.14](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_apolonio). Definición con *áreas aplicadas* de las *curvas cónicas* y el origen de sus nombres..
#    - [Figura 4.17](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_directriz). Definición de las cónicas usando la recta directriz y el foco..
# - Figuras en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#    - [Figura 4.18](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la elipse referidos al apside O, el foco F y el centro C: $a$ semieje mayor, $b$ semieje menor, $p$ *semilatus rectum*, $e$ excentricidad, $c$ distancia foco-centro..
#    - [Figura 4.20](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la hipérbola referidos al apside O, el foco F y el vértice C: $a$ distancia al vértice (llamado con frecuencia también semieje mayor aunque en la hipérbola no hay tal), $.
# - Figuras en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#    - [Figura 4.24](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:conica_foco). Derivación de la ecuación de la cónica en coordenadas cilíndricas referidas al Foco.  En la figura el ángulo $f$ es la *anomalía verdadera*..
#    - [Figura 4.27](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:anomalia_excentrica). Definición de la anomalía excéntrica $E$ y el método asociada a ella para determinar la posición de los puntos sobre una elipse..
# - Figuras en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#    - [Figura 4.30](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#fig:conicas_area). Construcción geométrica usada aquí para deducir la relación entre las anomalías $f$, $E$ y $F$ y el área del sector de cónica (región sombreada)..
# - Figuras en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#    - [Figura 4.31](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#fig:angulos_euler). Secuencia de rotaciones que permiten pasar del sistema natural de ejes de la cónica $x-y-z$ a un sistema con una orientación arbitraria $x'''-y'''-z'''$.
# - Figuras en [04.03.00.00.Fundamentos.ProblemasSeleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb)
#    - [Figura 4.35](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:elipse). Una elipse con algunos puntos resaltados..
#    - [Figura 4.36](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:latlon). Definición de elas coordenadas de latitud y longitud sobre la Tierra.

# %% [markdown]
# ## Índice de ecuaciones
# - Ecuaciones en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#     - [Ec. (4.1)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Asuma_tuplas): suma_tuplas.
#     - [Ec. (4.2)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Ak_tupla): k_tupla.
#     - [Ec. (4.3)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Avectores_en_base): vectores_en_base.
#     - [Ec. (4.4)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Adelta_kroenecker): delta_kroenecker.
#     - [Ec. (4.5)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Abase_mano_derecha): base_mano_derecha.
#     - [Ec. (4.6)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Alevi_civita): levi_civita.
#     - [Ec. (4.7)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz): producto_cruz.
#     - [Ec. (4.8)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz_determinante): producto_cruz_determinante.
#     - [Ec. (4.9)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_escalar): triple_producto_escalar.
#     - [Ec. (4.10)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_vectorial): triple_producto_vectorial.
#     - [Ec. (4.11)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aconjunto_mano_derecha): conjunto_mano_derecha.
#     - [Ec. (4.12)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Acilindricas_a_cartesianas): cilindricas_a_cartesianas.
#     - [Ec. (4.13)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_cilindricas): unitarios_cilindricas.
#     - [Ec. (4.14)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aesfericas_a_cartesianas): esfericas_a_cartesianas.
#     - [Ec. (4.15)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_esfericas): unitarios_esfericas.
# - Ecuaciones en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Ec. (4.16)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aderivada_definicion): derivada_definicion.
#     - [Ec. (4.17)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_general): regla_cadena_general.
#     - [Ec. (4.18)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cartesianas): gradiente_cartesianas.
#     - [Ec. (4.19)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cilindricas): gradiente_cilindricas.
#     - [Ec. (4.20)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_esfericas): gradiente_esfericas.
#     - [Ec. (4.21)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_multivariables): regla_cadena_multivariables.
#     - [Ec. (4.22)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Ateorema_fundamental_calculo): teorema_fundamental_calculo.
# - Ecuaciones en [04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb)
#     - [Ec. (4.23)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_antiderivada): ecuacion_diferencial_antiderivada.
#     - [Ec. (4.24)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple): ecuacion_diferencial_simple.
#     - [Ec. (4.25)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_reducida): ecuacion_diferencial_simple_reducida.
#     - [Ec. (4.26)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuaciones_reducidas): ecuaciones_reducidas.
#     - [Ec. (4.27)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_identificacion): ecuacion_diferencial_simple_identificacion.
# - Ecuaciones en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Ec. (4.28)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Avariacion): variacion.
#     - [Ec. (4.29)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Alongitud_curva): longitud_curva.
#     - [Ec. (4.30)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Afuncional_integral): funcional_integral.
#     - [Ec. (4.31)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3AdIdepsilon): dIdepsilon.
#     - [Ec. (4.32)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_integral_variaciones): ecuacion_integral_variaciones.
#     - [Ec. (4.33)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_euler_lagrange): ecuacion_euler_lagrange.
# - Ecuaciones en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#     - [Ec. (4.34)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_apside): ecuacion_apside.
#     - [Ec. (4.35)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon): conica_razon.
#     - [Ec. (4.36)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon_cartesianas): conica_razon_cartesianas.
#     - [Ec. (4.37)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz): ecuacion_directriz.
#     - [Ec. (4.38)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aalpha): alpha.
#     - [Ec. (4.39)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aq): q.
#     - [Ec. (4.40)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz_trasladada): ecuacion_directriz_trasladada.
#     - [Ec. (4.41)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aeta_apolonio): eta_apolonio.
# - Ecuaciones en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Ec. (4.42)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_apside_pe): ecuacion_apside_pe.
#     - [Ec. (4.43)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Atraslacion_centro): traslacion_centro.
#     - [Ec. (4.44)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemayor): semiejemayor.
#     - [Ec. (4.45)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro): ecuacion_centro.
#     - [Ec. (4.46)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemenor): semiejemenor.
#     - [Ec. (4.47)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro_hiperbola): ecuacion_centro_hiperbola.
#     - [Ec. (4.48)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Abeta): beta.
#     - [Ec. (4.49)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Acos_psi): cos_psi.
#     - [Ec. (4.50)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d): rotacion2d.
#     - [Ec. (4.51)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_matricial): rotacion2d_matricial.
#     - [Ec. (4.52)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Amatriz_rotacion2d): matriz_rotacion2d.
#     - [Ec. (4.53)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ainversa_matriz_rotacion): inversa_matriz_rotacion.
#     - [Ec. (4.54)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa_matricial): rotacion2d_inversa_matricial.
#     - [Ec. (4.55)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa): rotacion2d_inversa.
#     - [Ec. (4.56)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_conica_trasladada_rotada): ecuacion_conica_trasladada_rotada.
#     - [Ec. (4.57)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general): ecuacion_general.
#     - [Ec. (4.58)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general_coeficientes): ecuacion_general_coeficientes.
#     - [Ec. (4.59)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aeta_ecuacion_general): eta_ecuacion_general.
#     - [Ec. (4.60)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ateta_ecuacion_general): teta_ecuacion_general.
#     - [Ec. (4.61)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aty_ecuacion_general): ty_ecuacion_general.
# - Ecuaciones en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Ec. (4.62)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aecuacion_foco): ecuacion_foco.
#     - [Ec. (4.63)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_f): conica_parametricas_f.
#     - [Ec. (4.64)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_ecuacion_cilindricas): conica_ecuacion_cilindricas.
#     - [Ec. (4.65)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_E): conica_parametricas_E.
#     - [Ec. (4.66)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_anomalia_excentrica): conica_anomalia_excentrica.
#     - [Ec. (4.67)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3AfE): fE.
#     - [Ec. (4.68)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Ahiperbola_parametrica_F): hiperbola_parametrica_F.
# - Ecuaciones en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#     - [Ec. (4.69)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector): area_sector.
#     - [Ec. (4.70)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PFQ): A_PFQ.
#     - [Ec. (4.71)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PQO): A_PQO.
#     - [Ec. (4.72)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_RQO): A_RQO.
#     - [Ec. (4.73)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_elipse): area_sector_elipse.
#     - [Ec. (4.74)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_elipse): area_elipse.
#     - [Ec. (4.75)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_hiperbola): area_sector_hiperbola.
#     - [Ec. (4.76)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_parabola): area_sector_parabola.
# - Ecuaciones en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Ec. (4.77)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_R): rotacion3d_observador_R.
#     - [Ec. (4.78)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_M): rotacion3d_observador_M.
#     - [Ec. (4.79)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_definicion): matrizM_definicion.
#     - [Ec. (4.80)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita): matrizM_explicita.
#     - [Ec. (4.81)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita_transpuesta): matrizM_explicita_transpuesta.
#     - [Ec. (4.82)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_R): rotacion3d_natural_R.
#     - [Ec. (4.83)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_M): rotacion3d_natural_M.
#     - [Ec. (4.84)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Aelementos_estado_f): elementos_estado_f.

# %% [markdown]
# ## Índice de códigos
# - Código en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#     - [Código (3.1)](03.00.00.00.Introduccion.ipynb#code:rutina_discriminante): rutina_discriminante.
#     - [Código (3.2)](03.00.00.00.Introduccion.ipynb#code:raiz_polinomio): raiz_polinomio.
#     - [Código (3.3)](03.00.00.00.Introduccion.ipynb#code:plot_sin): plot_sin.
# - Código en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Código (4.4)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:rutina_potencial): rutina_potencial.
#     - [Código (4.5)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:funcion_lambda): funcion_lambda.
# - Código en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Código (4.6)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:funcional_integral): funcional_integral.
#     - [Código (4.7)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:minimiza_arco): minimiza_arco.
# - Código en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Código (4.8)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:spice_rotate): spice_rotate.
#     - [Código (4.9)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:rota_puntos): rota_puntos.
#     - [Código (4.10)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:polinomio_segundo_grado): polinomio_segundo_grado.
# - Código en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Código (4.11)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:conica_dibujo): conica_dibujo.
#     - [Código (4.12)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:puntos_conica): puntos_conica.
# - Código en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Código (4.13)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_explicito): calculo_M_explicito.
#     - [Código (4.14)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_general): calculo_M_general.
#     - [Código (4.15)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:conica_de_elementos): conica_de_elementos.
