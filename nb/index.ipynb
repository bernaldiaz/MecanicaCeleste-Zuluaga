# %% [markdown]
# <p style="margin:3em"></p>
# <p style="text-align:center;font-size:3em;font-weight:bold">Mecánica Celeste</p>
# <p style="text-align:center;font-size:2em">Teoría, algoritmos y problemas</p>

# %% [markdown]
# ![Portada](./figures/portada.png)

# %% [markdown]
# <p style="text-align:center;font-size:2em;font-weight:bold">Jorge I. Zuluaga</p>
# <p style="text-align:center;font-size:1.2em">Profesor Titular de Física y Astronomía</p>
# <p style="text-align:center;font-size:1.2em">Instituto de Física, Facultad de Ciencias Exactas y Naturales</p>
# <p style="text-align:center;font-size:1.2em">Universidad de Antioquia</p>

# %% [markdown]
# ---

# %% [markdown]
# <p style="margin:1em"></p>
# <p style="text-align:center;font-size:2em;font-weight:bold">Tabla de Contenido</p>
# <p style="margin:1em"></p>

# %% [markdown]
# ## Índice de materias
# - [Prefacio](01.00.00.00.Prefacio.ipynb#prefacio). <b>{#prefacio}</b>
#    - [¿Otro libro de mecánica celeste?](01.00.00.00.Prefacio.ipynb#otro_libro). <b>{#otro_libro}</b>
#    - [Mecánica celeste y mecánica analítica](01.00.00.00.Prefacio.ipynb#celeste_analitica). <b>{#celeste_analitica}</b>
#    - [Mecánica celeste en la era de la información](01.00.00.00.Prefacio.ipynb#celeste_era_informacion). <b>{#celeste_era_informacion}</b>
#    - [Mecánica celeste en Python](01.00.00.00.Prefacio.ipynb#celeste_python). <b>{#celeste_python}</b>
#    - [Mecánica celeste con `SPICE`](01.00.00.00.Prefacio.ipynb#celeste_spice). <b>{#celeste_spice}</b>
#    - [¿Qué hace distinto a este libro?: un decálogo](01.00.00.00.Prefacio.ipynb#libro_distinto). <b>{#libro_distinto}</b>
# - [Agradecimientos](02.00.00.00.Agradecimientos.ipynb#agradecimientos). <b>{#agradecimientos}</b>
# - [Introducción](03.00.00.00.Introduccion.ipynb#introduccion). <b>{#introduccion}</b>
#    - [¿Cómo se organiza este libro?](03.00.00.00.Introduccion.ipynb#organizacion_libro). <b>{#organizacion_libro}</b>
#    - [¿Cómo usar este libro?](03.00.00.00.Introduccion.ipynb#como_usar_libro). <b>{#como_usar_libro}</b>
#    - [Mecánica celeste en *libretas*](03.00.00.00.Introduccion.ipynb#celeste_libretas). <b>{#celeste_libretas}</b>
#       - [Instalación de las libretas](03.00.00.00.Introduccion.ipynb#instalacion_libretas). <b>{#instalacion_libretas}</b>
#    - [Idioma y Notación](03.00.00.00.Introduccion.ipynb#idioma_notacion). <b>{#idioma_notacion}</b>
#       - [Extranjerismos y pronunciación](03.00.00.00.Introduccion.ipynb#extranjerismos_pronunciacion). <b>{#extranjerismos_pronunciacion}</b>
#       - [Siglos y décadas](03.00.00.00.Introduccion.ipynb#siglos_decadas). <b>{#siglos_decadas}</b>
#       - [Notación matemática](03.00.00.00.Introduccion.ipynb#notacion). <b>{#notacion}</b>
#    - [Estructura del libro](03.00.00.00.Introduccion.ipynb#estructura_libro). <b>{#estructura_libro}</b>
#       - [Cajas de texto](03.00.00.00.Introduccion.ipynb#cajas_texto). <b>{#cajas_texto}</b>
#       - [Algorítmos](03.00.00.00.Introduccion.ipynb#algoritmos). <b>{#algoritmos}</b>
#    - [Figuras interactivas y animaciones](03.00.00.00.Introduccion.ipynb#interactivas_animaciones). <b>{#interactivas_animaciones}</b>
#       - [Ejemplo de figura interactiva](03.00.00.00.Introduccion.ipynb#ejemplo_interactiva). <b>{#ejemplo_interactiva}</b>
#       - [Ejemplo de figura animada](03.00.00.00.Introduccion.ipynb#ejemplo_animada). <b>{#ejemplo_animada}</b>
# - [Fundamentos](04.00.00.00.Fundamentos.ipynb#fundamentos). <b>{#fundamentos}</b>
#    - [Vectores y cálculo](04.01.00.00.Fundamentos.Calculo.ipynb#vectores_calculo). <b>{#vectores_calculo}</b>
#       - [Conjunto, tuplas y vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#conjuntos_tuplas_vectores). <b>{#conjuntos_tuplas_vectores}</b>
#       - [Sistemas de coordenadas](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#sistemas_coordenadas). <b>{#sistemas_coordenadas}</b>
#       - [Funciones](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones). <b>{#funciones}</b>
#       - [Derivadas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#derivadas). <b>{#derivadas}</b>
#       - [Funciones homogéneas](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#funciones_homogeneas). <b>{#funciones_homogeneas}</b>
#          - [Algoritmos para la derivada](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_derivada). <b>{#algoritmos_derivada}</b>
#       - [Integrales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales). <b>{#integrales}</b>
#       - [Integrales vectoriales](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#integrales_vectoriales). <b>{#integrales_vectoriales}</b>
#          - [Algoritmos para la integral](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#algoritmos_integral). <b>{#algoritmos_integral}</b>
#       - [Ecuaciones diferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#ecuaciones_diferenciales). <b>{#ecuaciones_diferenciales}</b>
#          - [Algoritmos para la solución de ODE](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#algoritmos_ode). <b>{#algoritmos_ode}</b>
#       - [Funcionales y cálculo de variaciones](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#funcionales_calculo_variaciones). <b>{#funcionales_calculo_variaciones}</b>
#          - [Algoritmos en el cálculo variacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#algoritmos_calculo_variacional). <b>{#algoritmos_calculo_variacional}</b>
#       - [Gráficos interactivos](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#graficos_interactivos_variacional). <b>{#graficos_interactivos_variacional}</b>
#    - [Curvas cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas). <b>{#conicas}</b>
#       - [Definición geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_definicion). <b>{#conicas_definicion}</b>
#       - [Del nombre al álgebra](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_nombre_algebra). <b>{#conicas_nombre_algebra}</b>
#       - [Directriz de las cónicas](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_directriz). <b>{#conicas_directriz}</b>
#       - [Síntesis geométrica](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#conicas_sintesis_geometrica). <b>{#conicas_sintesis_geometrica}</b>
#       - [Descripción algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_algebra). <b>{#conicas_algebra}</b>
#       - [Ecuación respecto al centro](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_centro). <b>{#conicas_centro}</b>
#       - [Eje mayor y menor de la elipse](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ejes). <b>{#conicas_ejes}</b>
#          - [Elipse interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#elipse_interactiva). <b>{#elipse_interactiva}</b>
#       - [Parámetros de la hipérbola](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#subsubsec_conicas_hiperbola). <b>{#subsubsec_conicas_hiperbola}</b>
#          - [Hipérbola interactiva](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#hiperbola_interactiva). <b>{#hiperbola_interactiva}</b>
#       - [Rotación de las cónicas en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_rotacion_plano). <b>{#conicas_rotacion_plano}</b>
#       - [Ecuación general de las cónicas](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_ecuacion_general). <b>{#conicas_ecuacion_general}</b>
#       - [Gráfico de una cónica rotada en el plano](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#grafico_conica_rotada_plano). <b>{#grafico_conica_rotada_plano}</b>
#       - [Síntesis algebraica](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#conicas_sintesis_algebraica). <b>{#conicas_sintesis_algebraica}</b>
#       - [Cónicas en coordenadas cilíndricas](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_cilindricas). <b>{#conicas_cilindricas}</b>
#       - [Anomalías](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#conicas_anomalias). <b>{#conicas_anomalias}</b>
#       - [Área de las cónicas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_conicas). <b>{#area_conicas}</b>
#          - [Área de un sector de elipse](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_elipse). <b>{#area_elipse}</b>
#          - [Área de un sector de hipérbola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_hiperbola). <b>{#area_hiperbola}</b>
#          - [Área de un sector de parábola](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#area_parábola). <b>{#area_parábola}</b>
#       - [Cónicas en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#conicas_espacio). <b>{#conicas_espacio}</b>
#       - [Ángulos de Euler](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#angulos_euler). <b>{#angulos_euler}</b>
#       - [Matrices de rotación generales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#matrices_rotacion_generales). <b>{#matrices_rotacion_generales}</b>
#       - [Gráfico de una cónica rotada en el espacio](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#grafico_conica_rotada_espacio). <b>{#grafico_conica_rotada_espacio}</b>
#       - [Elementos orbitales](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#elementos_orbitales). <b>{#elementos_orbitales}</b>
#    - [Problemas seleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fundamentos_problemas). <b>{#fundamentos_problemas}</b>
# - [Mecánica de partículas](05.00.00.00.Mecanica.ipynb#mecanica). <b>{#mecanica}</b>
#    - [Cinemática](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#cinematica). <b>{#cinematica}</b>
#       - [Cantidades cinemáticas](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#cantidades_cinematicas). <b>{#cantidades_cinematicas}</b>
#       - [Sistemas de referencia](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#sistemas_referencia). <b>{#sistemas_referencia}</b>
#       - [La ecuación de movimiento (e.d.m.)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#ecuacion_movimiento). <b>{#ecuacion_movimiento}</b>
#       - [Integración de la e.d.m.](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#integracion_edm). <b>{#integracion_edm}</b>
#       - [Integración por cuadraturas](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#integracion_cuadraturas). <b>{#integracion_cuadraturas}</b>
#       - [Integración numérica de la e.d.m.](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#integracion_numerica_edm). <b>{#integracion_numerica_edm}</b>
#    - [Dinámica](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#dinamica). <b>{#dinamica}</b>
#       - [Cantidades dinámicas](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#cantidades_dinamicas). <b>{#cantidades_dinamicas}</b>
#       - [Partículas y fuerzas](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#particulas_fuerzas). <b>{#particulas_fuerzas}</b>
#       - [Sistemas de referencia inerciales](05.02.00.00.Mecanica.Dinamica.Cantidades.ipynb#sistemas_referencia_inerciales). <b>{#sistemas_referencia_inerciales}</b>
#       - [Postulado de fuerzas](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_fuerzas). <b>{#postulado_fuerzas}</b>
#       - [Fuerzas conservativas y no conservativas](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fuerzas_conservativas). <b>{#fuerzas_conservativas}</b>
#       - [Energía mecánica](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#energia_mecanica). <b>{#energia_mecanica}</b>
#       - [¿Ley de inercia?](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#ley_inercia). <b>{#ley_inercia}</b>
#       - [Postulado de acción y reacción](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_accion_reaccion). <b>{#postulado_accion_reaccion}</b>
#       - [Postulado de gravitación universal](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#postulado_gravitacion). <b>{#postulado_gravitacion}</b>
#       - [La fuerza gravitacional de la Tierra, el Sol y la la Luna](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fuerza_luna). <b>{#fuerza_luna}</b>
#       - [El campo gravitacional](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#campo_gravitacional). <b>{#campo_gravitacional}</b>
#       - [Energía potencial gravitacional](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#energia_potencial_gravitacional). <b>{#energia_potencial_gravitacional}</b>
#       - [Masa y principio de equivalencia](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#masa_equivalencia). <b>{#masa_equivalencia}</b>
#    - [Sistemas de partículas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#sistemas_particulas). <b>{#sistemas_particulas}</b>
#       - [Fuerzas y centro de masa](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fuerzas_centro_masa). <b>{#fuerzas_centro_masa}</b>
#       - [Centro de masa de un sistema de dos partículas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#centro_masa). <b>{#centro_masa}</b>
#       - [Teoremas de conservación](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#teoremas_conservacion). <b>{#teoremas_conservacion}</b>
#       - [Dinámica referida al centro de masa](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#dinamica_centro_masa). <b>{#dinamica_centro_masa}</b>
#    - [Dinámica en sistemas de referencia no inerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#sistemas_no_inerciales). <b>{#sistemas_no_inerciales}</b>
#       - [Transformación entre sistemas de referencia](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#transformacion_sistemas_referencia). <b>{#transformacion_sistemas_referencia}</b>
#       - [Sistemas de referencia rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#sistemas_rotantes). <b>{#sistemas_rotantes}</b>
#       - [Adición de velocidades en sistemas rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#adicion_velocidades_rotantes). <b>{#adicion_velocidades_rotantes}</b>
#       - [Aceleraciones ficticias en sistemas rotantes](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#aceleraciones_ficticias_rotantes). <b>{#aceleraciones_ficticias_rotantes}</b>
#       - [Un ejemplo numérico](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb#ejemplo_numerico_rotante). <b>{#ejemplo_numerico_rotante}</b>
#    - [Problemas seleccionados](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb#mecanica_problemas). <b>{#mecanica_problemas}</b>
# - [El Problema de los N cuerpos](06.00.00.00.ProblemaNCuerpos.ipynb#problema_ncuerpos). <b>{#problema_ncuerpos}</b>
#    - [Formulación del problema](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#ncuerpos_formulacion). <b>{#ncuerpos_formulacion}</b>
#       - [Motivación](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#ncuerpos_motivacion). <b>{#ncuerpos_motivacion}</b>
#       - [Enunciado físico y matemático](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#ncuerpos_enunciado). <b>{#ncuerpos_enunciado}</b>
#    - [¿Solución analítica?](06.02.00.00.ProblemaNCuerpos.SolucionAnalitica.ipynb#solucion_analitica). <b>{#solucion_analitica}</b>
#       - [Aplicación de los teoremas de conservación](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#ncuerpos_teoremas_conservacion). <b>{#ncuerpos_teoremas_conservacion}</b>
#       - [Momento lineal](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#ncuerpos_momento). <b>{#ncuerpos_momento}</b>
#       - [Posición del centro de masa](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#ncuerpos_centro_masa). <b>{#ncuerpos_centro_masa}</b>
#       - [Momentum angular](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#ncuerpos_momento_angular). <b>{#ncuerpos_momento_angular}</b>
#       - [Energía potencial de N cuerpos](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#ncuerpos_potencial). <b>{#ncuerpos_potencial}</b>
#       - [Conservación de la energía](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#ncuerpos_energia). <b>{#ncuerpos_energia}</b>
#       - [Caso de estudio: el sistema Tierra-Luna](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#energia_tierra_luna). <b>{#energia_tierra_luna}</b>
#       - [Síntesis y teorema de Bruns](06.02.03.00.ProblemaNCuerpos.SolucionAnalitica.Sintesis.ipynb#ncuerpos_teorema_bruns). <b>{#ncuerpos_teorema_bruns}</b>
#    - [Energía y virial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#ncuerpos_virial). <b>{#ncuerpos_virial}</b>
#       - [Momento de inercia](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#ncuerpos_momento_inercia). <b>{#ncuerpos_momento_inercia}</b>
#       - [El virial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#virial). <b>{#virial}</b>
#       - [Identidad de Lagrange-Jacobi](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#identidad_lagrange_jacobi). <b>{#identidad_lagrange_jacobi}</b>
#       - [Teorema del virial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#teorema_virial). <b>{#teorema_virial}</b>
#       - [Caso de estudio: la masa de cúmulos de galaxias](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#masa_cumulos_galaxias). <b>{#masa_cumulos_galaxias}</b>
#    - [Solución numérica](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_solucion_numerica). <b>{#ncuerpos_solucion_numerica}</b>
#       - [Unidades canónicas](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#unidades_canonicas). <b>{#unidades_canonicas}</b>
#       - [Las ecuaciones de movimiento reducidas](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_edmr). <b>{#ncuerpos_edmr}</b>
#       - [Algoritmo de solucion](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_algoritmo_solucion). <b>{#ncuerpos_algoritmo_solucion}</b>
#       - [Figuras interactivas](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_numerico_interactivas). <b>{#ncuerpos_numerico_interactivas}</b>
#          - [El problema de los N cuerpos interactivo](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_numerico_interactivos). <b>{#ncuerpos_numerico_interactivos}</b>
#          - [Animación del problema de los N cuerpos](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#ncuerpos_numerico_animacion). <b>{#ncuerpos_numerico_animacion}</b>
#       - [Constantes de movimiento y teorema del virial](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb#ncuerpos_numerico_constantes_virial). <b>{#ncuerpos_numerico_constantes_virial}</b>
#       - [Una algoritmo general](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb#ncuerpos_algoritmo_general). <b>{#ncuerpos_algoritmo_general}</b>
#    - [Problemas seleccionados](06.03.00.00.ProblemaNCuerpos.ProblemasSeleccionados.ipynb#ncuerpos_problemas). <b>{#ncuerpos_problemas}</b>
# - [El Problema de los dos cuerpos](07.00.00.00.Problema2Cuerpos.ipynb#problema_doscuerpos). <b>{#problema_doscuerpos}</b>
#    - [Motivación](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb#doscuerpos_motivación). <b>{#doscuerpos_motivación}</b>
#    - [El problema relativo de dos cuerpos](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_reducido). <b>{#doscuerpos_reducido}</b>
#    - [Constantes de movimiento](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_constantes). <b>{#doscuerpos_constantes}</b>
#       - [Momento angular específico relativo](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_h). <b>{#doscuerpos_h}</b>
#       - [Energía específica relativa](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_epsilon). <b>{#doscuerpos_epsilon}</b>
#       - [El vector de excentricidad](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_e). <b>{#doscuerpos_e}</b>
#    - [La ecuación de la trayectoria](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_ecuacion). <b>{#doscuerpos_ecuacion}</b>
#    - [La velocidad relativa](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#doscuerpos_velocidad). <b>{#doscuerpos_velocidad}</b>
#    - [El hodográfo del problema de los dos cuerpos](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#hodografo_doscuerpos). <b>{#hodografo_doscuerpos}</b>
#    - [El teorema armónico](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#teorema_armónico). <b>{#teorema_armónico}</b>
#    - [Teoremas del movimiento orbital](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#teoremas_orbital). <b>{#teoremas_orbital}</b>
#    - [La órbita en el espacio](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#orbita_espacio). <b>{#orbita_espacio}</b>
#       - [Determinación de la órbita](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#determinacion_orbita). <b>{#determinacion_orbita}</b>
#       - [Predicción del vector de estado](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#prediccion_estado). <b>{#prediccion_estado}</b>
#       - [La órbita osculatriz](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#orbita_osculatriz). <b>{#orbita_osculatriz}</b>
#       - [Un ejemplo numérico](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#ejemplo_numerico_orbita_espacio). <b>{#ejemplo_numerico_orbita_espacio}</b>
#    - [El problema de los dos cuerpos en el tiempo](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#doscuerpos_tiempo). <b>{#doscuerpos_tiempo}</b>
#       - [La ecuación de Halley](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#ecuacion_halley). <b>{#ecuacion_halley}</b>
#       - [La ecuación de Kepler](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#ecuacion_kepler). <b>{#ecuacion_kepler}</b>
#       - [La función generalizada de Kepler](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#funcion_kepler). <b>{#funcion_kepler}</b>
#       - [Interpretación geométrica de la anomalía media](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#interpretacion_M). <b>{#interpretacion_M}</b>
#       - [Solución numérica a la ecuación de Kepler](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#solucion_kepler_numerica). <b>{#solucion_kepler_numerica}</b>
#          - [El Método de Kepler](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_metodo_kepler). <b>{#kepler_metodo_kepler}</b>
#          - [Método del punto fijo](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_metodo_puntofijo). <b>{#kepler_metodo_puntofijo}</b>
#          - [Método de Newton-Raphson](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_metodo_newton). <b>{#kepler_metodo_newton}</b>
#          - [El método de Laguerre-Conway](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_laguerre). <b>{#kepler_laguerre}</b>
#          - [Métodos de horquillado](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_horquillado). <b>{#kepler_horquillado}</b>
#          - [Otros métodos](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_otros_metodos). <b>{#kepler_otros_metodos}</b>
#       - [Solución analítica por aproximaciones sucesivas](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#solucion_kepler_aproximacions). <b>{#solucion_kepler_aproximacions}</b>
#       - [Solución por series de la ecuación de Kepler](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#solucion_kepler_series). <b>{#solucion_kepler_series}</b>
#       - [Eficiencia de los métodos de solución](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#kepler_precision_eficiencia). <b>{#kepler_precision_eficiencia}</b>
#    - [Una síntesis del problema de los dos cuerpos](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb#doscuerpos_sintesis). <b>{#doscuerpos_sintesis}</b>
#       - [Un ejemplo numérico](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb#ejemplo_numerico_doscuerpos_sintesis). <b>{#ejemplo_numerico_doscuerpos_sintesis}</b>
#    - [Variables universales](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#variables_universales). <b>{#variables_universales}</b>
#       - [Las funciones $f$ y $g$](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#funciones_fg). <b>{#funciones_fg}</b>
#    - [Aproximación de dos cuerpos a sistemas jerárquicos](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#doscuerpos_aproximacion). <b>{#doscuerpos_aproximacion}</b>
#       - [Predicciones en el Sistema Solar](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#doscuerpos_sistema_solar). <b>{#doscuerpos_sistema_solar}</b>
#       - [Evolución de los elementos orbitales osculatrices](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#doscuerpos_evolucion_elementos). <b>{#doscuerpos_evolucion_elementos}</b>
#       - [Un ejemplo real: los elementos osculatrices de la Luna](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#elementos_luna). <b>{#elementos_luna}</b>
#    - [Introducción a la teoría de perturbaciones](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#teoria_perturbaciones). <b>{#teoria_perturbaciones}</b>
#       - [Perturbación del semieje mayor](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#perturbacion_a). <b>{#perturbacion_a}</b>
#       - [Perturbación de la excéntricidad](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#perturbacion_e). <b>{#perturbacion_e}</b>
#       - [Perturbaciones de la orientación](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#perturbacion_orientacion). <b>{#perturbacion_orientacion}</b>
#       - [Un ejemplo numérico](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#perturbaciones_ejemplo). <b>{#perturbaciones_ejemplo}</b>
#    - [El problema de los dos cuerpos en `SPICE`](07.07.00.00.Problema2Cuerpos.SPICE.ipynb#doscuerpos_SPICE). <b>{#doscuerpos_SPICE}</b>
#    - [Problemas seleccionados](07.07.00.00.Problema2Cuerpos.ProblemasSeleccionados.ipynb#doscuerpos_problemas). <b>{#doscuerpos_problemas}</b>
# - [El problema restringido de los tres cuerpos](08.00.00.00.Problema3Cuerpos.ipynb#problema_tres_cuerpos). <b>{#problema_tres_cuerpos}</b>
#    - [Motivación](08.00.00.00.Problema3Cuerpos.Motivacion.ipynb#trescuerpos_motivacion). <b>{#trescuerpos_motivacion}</b>
#    - [El problema restringido de los tres cuerpos](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#rtbp). <b>{#rtbp}</b>
#    - [El problema circular restringido de los tres cuerpos (CRTBP)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#crtbp). <b>{#crtbp}</b>
#    - [Las unidades canónicas del CRTBP](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#unidades_crtbp). <b>{#unidades_crtbp}</b>
#    - [Solución numérica al CRTBP](08.01.00.00.Problema3Cuerpos.CRTBP.Numerico.ipynb#crtbp_numerico). <b>{#crtbp_numerico}</b>
#    - [Un algoritmo general para el CRTBP](08.01.00.00.Problema3Cuerpos.CRTBP.Numerico.ipynb#crtbp_algoritmo). <b>{#crtbp_algoritmo}</b>
#       - [Animaciones](08.01.00.00.Problema3Cuerpos.CRTBP.Numerico.ipynb#crtbp_animaciones). <b>{#crtbp_animaciones}</b>
#    - [La constante de Jacobi](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#CRTBP_constante_jacobi). <b>{#CRTBP_constante_jacobi}</b>
#    - [El valor de la constante de Jacobi](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#constante_jacobi_valor). <b>{#constante_jacobi_valor}</b>
#    - [Cuadratura de Jacobi de un sistema simulado](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#constante_jacobi_simulado). <b>{#constante_jacobi_simulado}</b>
#    - [Cuadratura de Jacobi de un sistema real](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#constante_jacobi_real). <b>{#constante_jacobi_real}</b>
#    - [Las regiones de exclusión](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#crtbp_regiones_exclusion). <b>{#crtbp_regiones_exclusion}</b>
#    - [El potencial modificado](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#crtbp_potencial_modificado). <b>{#crtbp_potencial_modificado}</b>
#    - [Los puntos de equilibrio de Lagrange](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_puntos_lagrange). <b>{#crtbp_puntos_lagrange}</b>
#       - [Puntos de equilibrio triangulares](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_puntos_triangulares). <b>{#crtbp_puntos_triangulares}</b>
#       - [Puntos de equilibrio colineales](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_puntos_colineales). <b>{#crtbp_puntos_colineales}</b>
#       - [Punto colineal de equilibrio, $L_1$](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_L1). <b>{#crtbp_L1}</b>
#       - [Punto colineal de equilibrio, $L_2$](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_L2). <b>{#crtbp_L2}</b>
#       - [Punto colineal de equilibrio, $L_3$](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#crtbp_L3). <b>{#crtbp_L3}</b>
#       - [El radio de Hill y el lóbulo de Roche](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb#crtbp_esfera_influencia). <b>{#crtbp_esfera_influencia}</b>
#       - [Órbitas periódicas cerca a los puntos de equilibrio](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#crtbp_orbitas_puntosequilibrio). <b>{#crtbp_orbitas_puntosequilibrio}</b>
#       - [El parámetro de Tisserand](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#trescuerpos_parametro_tisserand). <b>{#trescuerpos_parametro_tisserand}</b>
#       - [Clasificación de los objetos cercanos a la Tierra (NEOs)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#T_NEOs_clasificacion). <b>{#T_NEOs_clasificacion}</b>
#       - [Clasificación de los objetos cercanos a Júpiter](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#T_jupiter_clasificacion). <b>{#T_jupiter_clasificacion}</b>
#    - [Problemas seleccionados](08.06.00.00.Problema3Cuerpos.ProblemasSeleccionados.ipynb#trescuerpos_problemas). <b>{#trescuerpos_problemas}</b>
# - [El formalismo lagrangiano](09.00.00.00.FormalismoLagrangiano.ipynb#formalismo_lagrangiano). <b>{#formalismo_lagrangiano}</b>
#    - [Motivación](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#lagrangiano_motivacion). <b>{#lagrangiano_motivacion}</b>
#    - [El formalismo Lagrangiano](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#formalismo_lagrangiano_introduccion). <b>{#formalismo_lagrangiano_introduccion}</b>
#       - [Principio de los trabajos virtuales](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#trabajos_virtuales). <b>{#trabajos_virtuales}</b>
#       - [Principio de d'Alambert-Lagrange](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#principio_dalambert_lagrange). <b>{#principio_dalambert_lagrange}</b>
#    - [Restricciones y variables generalizadas](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#restricciones_variables_generalizadas). <b>{#restricciones_variables_generalizadas}</b>
#       - [Fuerzas de restricción](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#fuerzas_restriccion). <b>{#fuerzas_restriccion}</b>
#       - [Variables generalizadas](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#variables_generalizadas). <b>{#variables_generalizadas}</b>
#       - [Propiedades matemáticas de las reglas de transformación](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#reglas_transformacion_propiedades). <b>{#reglas_transformacion_propiedades}</b>
#    - [Las ecuaciones de Lagrange](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#ecuaciones_lagrange). <b>{#ecuaciones_lagrange}</b>
#       - [Un ejemplo: el péndulo elástico](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#pendulo_elastico). <b>{#pendulo_elastico}</b>
#    - [La función lagrangiana](09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana.ipynb#funcion_lagrangiana). <b>{#funcion_lagrangiana}</b>
#       - [El potencial generalizado](09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana.ipynb#potencial_generalizado). <b>{#potencial_generalizado}</b>
#       - [Un ejemplo: el Lagrangiano del péndulo elástico](09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana.ipynb#lagrangiano_pendulo_elastico). <b>{#lagrangiano_pendulo_elastico}</b>
#    - [El principio de Hamilton](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#principio_hamilton). <b>{#principio_hamilton}</b>
#       - [Un ejemplo: el péndulo simple](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#hamilton_pendulo_simple). <b>{#hamilton_pendulo_simple}</b>
#    - [Simetrías y leyes de conservación](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#simetrias_conservacion). <b>{#simetrias_conservacion}</b>
#       - [Conservación del momento angular](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#simetrias_momento_angular). <b>{#simetrias_momento_angular}</b>
#       - [Conservación del momento lineal](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#simetrias_momento_lineal). <b>{#simetrias_momento_lineal}</b>
#       - [Variables cíclicas](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#variables_ciclicas). <b>{#variables_ciclicas}</b>
#       - [La función de Jacobi y la conservación de la energía](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#funcion_jacobi). <b>{#funcion_jacobi}</b>
#    - [Mecánica celeste en el formalismo Lagrangiano](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ipynb#celeste_lagrangiano). <b>{#celeste_lagrangiano}</b>
#       - [El Lagrangiano de N cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#ncuerpos_lagrangiano). <b>{#ncuerpos_lagrangiano}</b>
#       - [Simetrías del lagrangiano de N cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#ncuerpos_lagrangiano_simetrias). <b>{#ncuerpos_lagrangiano_simetrias}</b>
#       - [El lagrangiano de un sistema de N cuerpos jerárquico](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#ncuerpos_jerarquico_lagrangiano). <b>{#ncuerpos_jerarquico_lagrangiano}</b>
#       - [El problema general de los dos cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#doscuerpos_general). <b>{#doscuerpos_general}</b>
#       - [El potencial efectivo y las regiones de exclusión](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#potencial_efectivo). <b>{#potencial_efectivo}</b>
#       - [Ecuación de movimiento de la variable radial](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#edm_variable_radial). <b>{#edm_variable_radial}</b>
#       - [Ecuación de la forma orbital](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#doscuerpos_general_ecuacionforma). <b>{#doscuerpos_general_ecuacionforma}</b>
#       - [El problema de los dos cuerpos con n arbitrario](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#doscuerpos_narbitrario). <b>{#doscuerpos_narbitrario}</b>
#    - [Problemas seleccionados](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#lagrangiano_problemas). <b>{#lagrangiano_problemas}</b>
# - [El formalismo hamiltoniano](10.00.00.00.FormalismoHamiltoniano.ipynb#formalismo_hamiltoniano). <b>{#formalismo_hamiltoniano}</b>
#    - [Motivación](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#hamiltoniano_motivacion). <b>{#hamiltoniano_motivacion}</b>
#       - [El problema de las ecuaciones de movimiento](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#hamiltoniano_motivacion_edm). <b>{#hamiltoniano_motivacion_edm}</b>
#       - [Degeneración del espacio de configuración](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#hamiltoniano_motivacion_degenracion). <b>{#hamiltoniano_motivacion_degenracion}</b>
#    - [Las ecuaciones de Hamilton](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#ecuaciones_hamilton). <b>{#ecuaciones_hamilton}</b>
#    - [Las ecuaciones canónicas de Hamilton](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#ecuaciones_canonicas). <b>{#ecuaciones_canonicas}</b>
#    - [El principio de Hamilton modificado](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#principio_hamilton_modificado). <b>{#principio_hamilton_modificado}</b>
#    - [Dinámica en el espacio de fase](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb#espacio_fase). <b>{#espacio_fase}</b>
#       - [El péndulo simple en el espacio de fase](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb#pendulo_fase). <b>{#pendulo_fase}</b>
#    - [Simetrías y candidates conservadas](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#hamiltoniano_simetrias). <b>{#hamiltoniano_simetrias}</b>
#       - [Variables cíclicas](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#hamiltoniano_variablesciclicas). <b>{#hamiltoniano_variablesciclicas}</b>
#       - [Un ejemplo: el péndulo cónico](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#hamiltoniano_pendulo_conico). <b>{#hamiltoniano_pendulo_conico}</b>
#       - [Conservación del Hamiltoniano](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#conservacion_hamiltoniano). <b>{#conservacion_hamiltoniano}</b>
#       - [Cantidades conservadas y los corchetes de Poisson](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#corchetes_poisson). <b>{#corchetes_poisson}</b>
#    - [Transformaciones canónicas](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#transformaciones_canonicas). <b>{#transformaciones_canonicas}</b>
#       - [La función generatriz](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#funcion_generatriz). <b>{#funcion_generatriz}</b>
#       - [Transformaciones canónicas básicas](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#transformaciones_canonicas_basicas). <b>{#transformaciones_canonicas_basicas}</b>
#    - [El método de Hamilton-Jacobi](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb#hamilton_jacobi). <b>{#hamilton_jacobi}</b>
#       - [Ejemplo 1: el oscilador armónico en una dimension](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb#hamilton_jacobi_mas_1d). <b>{#hamilton_jacobi_mas_1d}</b>
#       - [Ejemplo 2: partícula en caída libre](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb#hamilton_jacobi_caida). <b>{#hamilton_jacobi_caida}</b>
#    - [Mecánica celeste en el formalismo hamiltoniano](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.ipynb#celeste_hamiltoniano). <b>{#celeste_hamiltoniano}</b>
#       - [El hamiltononiano del problema de los dos cuerpos](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb#hamiltoniano_doscuerpos). <b>{#hamiltoniano_doscuerpos}</b>
#       - [Conservación del vector de excentricidad](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb#conservacion_e). <b>{#conservacion_e}</b>
#       - [El método de Hamilton-Jacobi en mecánica celeste](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#hamilton_jacobi_celeste). <b>{#hamilton_jacobi_celeste}</b>
#       - [El espacio de fase de los elementos orbitales](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#fase_elementos_orbitales). <b>{#fase_elementos_orbitales}</b>
#       - [Las variables de Delaunay](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#variables_delaunay). <b>{#variables_delaunay}</b>
#    - [Problemas seleccionados](10.04.00.00.FormalismoHamiltoniano.ProblemasSeleccionados.ipynb#hamiltoniano_problemas). <b>{#hamiltoniano_problemas}</b>
# - [Algoritmos y rutinas útiles](11.00.00.00.ApendiceAlgoritmos.ipynb#algoritmos_utiles). <b>{#algoritmos_utiles}</b>

# %% [markdown]
# ## Índice de figuras
# - Figuras en [01.00.00.00.Prefacio](01.00.00.00.Prefacio.ipynb)
#    - [Figura 1.1](01.00.00.00.Prefacio.ipynb#fig:utlima_thule). Imagen procesada de Ultima Thule, el objeto transneptuniano sobrevolado por la sonda New Horizons en 2019 (crédito: NASA/Johns Hopkins University Applied Physics Laboratory/Southwest Research Institute/Roman Tkachenko.). <b>{fig:utlima_thule}</b>
# - Figuras en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#    - [Figura 3.3](03.00.00.00.Introduccion.ipynb#fig:kepler). Retrato de Johanes Kepler, copia de un original de 1610 de pintor desconocido y que se conserva en el monasterio Benedictino de Kremsmünster. <b>{fig:kepler}</b>
# - Figuras en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#    - [Figura 4.6](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:vectores). Definición geométrica de vector espacial y de sus operaciones básicas (suma, resta y multiplicación por un escalar). Aunque la resta de $. <b>{fig:vectores}</b>
#    - [Figura 4.7](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#fig:coordenadas). Definción de los sistemas de coordenadas usadas en este texto. <b>{fig:coordenadas}</b>
# - Figuras en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#    - [Figura 4.9](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#fig:variacion_funcion). El área bajo una curva es un funcional, en tanto depende de la función que represente la curva, $f(t)$ o $f_0(t)$ Se conoce como una variación $. <b>{fig:variacion_funcion}</b>
# - Figuras en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#    - [Figura 4.12](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_definicion). Definición geométrica original de las *curvas cónicas*.. <b>{fig:conicas_definicion}</b>
#    - [Figura 4.13](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_apolonio). Definición con *áreas aplicadas* de las *curvas cónicas* y el origen de sus nombres.. <b>{fig:conicas_apolonio}</b>
#    - [Figura 4.16](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#fig:conicas_directriz). Definición de las cónicas usando la recta directriz y el foco.. <b>{fig:conicas_directriz}</b>
# - Figuras en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#    - [Figura 4.17](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la elipse referidos al apside O, el foco F y el centro C: $a$ semieje mayor, $b$ semieje menor, $p$ *semilatus rectum*, $e$ excentricidad, $c$ distancia foco-centro.. <b>{fig:elipse}</b>
#    - [Figura 4.19](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#fig:elipse). Parámetros geométricos de la hipérbola referidos al apside O, el foco F y el vértice C: $a$ distancia al vértice (llamado con frecuencia también semieje mayor aunque en la hipérbola no hay tal), $. <b>{fig:elipse}</b>
# - Figuras en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#    - [Figura 4.23](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:conica_foco). Derivación de la ecuación de la cónica en coordenadas cilíndricas referidas al Foco.  En la figura el ángulo $f$ es la *anomalía verdadera*.. <b>{fig:conica_foco}</b>
#    - [Figura 4.26](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#fig:anomalia_excentrica). Definición de la anomalía excéntrica $E$ y el método asociada a ella para determinar la posición de los puntos sobre una elipse.. <b>{fig:anomalia_excentrica}</b>
# - Figuras en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#    - [Figura 4.29](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#fig:conicas_area). Construcción geométrica usada aquí para deducir la relación entre las anomalías $f$, $E$ y $F$ y el área del sector de cónica (región sombreada).. <b>{fig:conicas_area}</b>
# - Figuras en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#    - [Figura 4.30](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#fig:angulos_euler). Secuencia de rotaciones que permiten pasar del sistema natural de ejes de la cónica $x-y-z$ a un sistema con una orientación arbitraria $x'''-y'''-z'''$. <b>{fig:angulos_euler}</b>
# - Figuras en [04.03.00.00.Fundamentos.ProblemasSeleccionados](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb)
#    - [Figura 4.34](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:elipse). Una elipse con algunos puntos resaltados.. <b>{fig:prob:elipse}</b>
#    - [Figura 4.35](04.03.00.00.Fundamentos.ProblemasSeleccionados.ipynb#fig:prob:latlon). Definición de elas coordenadas de latitud y longitud sobre la Tierra. <b>{fig:prob:latlon}</b>
# - Figuras en [05.01.01.00.Mecanica.Cinematica.Cantidades](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb)
#    - [Figura 5.36](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#fig:transformaciones_galileo). Construcción geométrica para deducir la regla de transformación de la posición $. <b>{fig:transformaciones_galileo}</b>
# - Figuras en [05.02.01.00.Mecanica.Dinamica.Postulados](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb)
#    - [Figura 5.40](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:principia). Fotografía de la copia persona de Newton de la primera edición de los *Principia*, incluyendo correcciones hechas a mano por el mismo Newton. Foto: Andrew Dunn, http://bit.ly/2WugALe.. <b>{fig:principia}</b>
#    - [Figura 5.41](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:accion_reaccion). Dos formas del postulado de acción y reacción: a la izquierda el postulado débil, en el que las fuerzas son iguales y de sentido contrario, pero no son paralelas a la línea que une las partículas; a la derecha el postulado fuerte en el que la acción y reacción actúan sobre la línea que une a las partículas.. <b>{fig:accion_reaccion}</b>
#    - [Figura 5.42](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:fuerza_gravitacional). Definición de los vectores de posición, vector relativo y vector de fuerza en el postulado de gravitación universal.. <b>{fig:fuerza_gravitacional}</b>
#    - [Figura 5.43](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:hooke). Robert Hooke (1635-1753). Crédito: Rita Greer (2004).. <b>{fig:hooke}</b>
#    - [Figura 5.44](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#fig:stevin). El único retrato disponible de Simon Stevin (ca. 1548). Crédito: Colección Universidad de Leiden.. <b>{fig:stevin}</b>
# - Figuras en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#    - [Figura 5.47](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fig:centro_masa). Relación entre la posición del centro de masa $. <b>{fig:centro_masa}</b>
#    - [Figura 5.48](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#fig:astronomia_nova). Primera página de la obra cumbre de Kepler *Astronomía Nova*.. <b>{fig:astronomia_nova}</b>
# - Figuras en [05.03.00.00.Mecanica.SistemasNoInerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb)
#    - [Figura 5.49](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:transformaciones_noinercial). Construcción geométrica para deducir la regla de transformación de la posición $. <b>{fig:transformaciones_noinercial}</b>
#    - [Figura 5.50](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:iss_microgravedad). Explicación de la experiencia de ingravidez en el interior de un vehículo espacial, en este caso un módulo de la Estación Espacial Internacional.  El módulo corresponde a un sistema de referencia no inercial con una aceleración $. <b>{fig:iss_microgravedad}</b>
#    - [Figura 5.51](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:rotacion_ejes). Construcción geométrica usada para calcular el cambio en la dirección de los vectores unitarios coordenados de un sistema de coordenadas cuando se produce una rotación alrededor de un eje arbitrario $. <b>{fig:rotacion_ejes}</b>
#    - [Figura 5.52](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:rotaciones_no_conmutativas). Las rotaciones, representadas aquí por $. <b>{fig:rotaciones_no_conmutativas}</b>
#    - [Figura 5.53](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:aceleraciones_ficticias). Explicación esquemática del origen y dirección de las aceleraciones centrífuga y de Coriolís.. <b>{fig:aceleraciones_ficticias}</b>
#    - [Figura 5.54](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#fig:coriolis). Gaspard-Gustave Coriolis (1792-1843) en un retrato de 1841.  Coriolís tuvo la suerte de que una de las más importantes aceleraciones ficticias que se producen en sistemas en rotación, y que habían sido identificada y descritas antes por varios físicos desde Laplace hasta Riccioli, llevara finalmente su nombre.. <b>{fig:coriolis}</b>
# - Figuras en [05.03.00.00.Mecanica.ProblemasSeleccionados](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb)
#    - [Figura 5.59](05.03.00.00.Mecanica.ProblemasSeleccionados.ipynb#fig:prob:lanzamiento_proyectil). Geometría del lanzamiento de un proyectil desde la superficie de una Tierra en rotación.. <b>{fig:prob:lanzamiento_proyectil}</b>
# - Figuras en [06.01.00.00.ProblemaNCuerpos.Formulacion](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb)
#    - [Figura 6.60](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#fig:ncuerpos_formulacion). El problema de los N cuerpos: dadas las condiciones iniciales de un conjunto de N partículas puntuales, predecir la posición y velocidad de las partículas en cualquier instante futuro.. <b>{fig:ncuerpos_formulacion}</b>
#    - [Figura 6.61](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#fig:henri_poincare). Fotografía de Henri Poincaré hacia el año 1886, unos años antes de realizar su trabajo histórico sobre el problema de los tres cuerpos (Foto: Eugène Pirou). <b>{fig:henri_poincare}</b>
# - Figuras en [06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb)
#    - [Figura 6.62](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#fig:plano_invariable). Ilustración gráfica de la orientación del plano invariable de Laplace.  El plano invariable esta definido en el sistema de referencia inercial del centro de masa y se mueve con él con velocidad $V_. <b>{fig:plano_invariable}</b>
# - Figuras en [06.03.00.00.ProblemaNCuerpos.TeoremaVirial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb)
#    - [Figura 6.64](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#fig:coma_cluster). Mosaico en falso color del cúmulo de Galaxias de Coma que combina imágenes en luz visible e infrarrojo. Crédito: NASA / JPL-Caltech / L. Jenkins (GSFC).. <b>{fig:coma_cluster}</b>
# - Figuras en [06.03.00.00.ProblemaNCuerpos.SolucionNumerica](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb)
#    - [Figura 6.65](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#fig:ncuerpos_numerico_ejemplo). Sistema de tres cuerpos de ejemplo (todas las cantidades están expresadas en unidades canónicas). <b>{fig:ncuerpos_numerico_ejemplo}</b>
# - Figuras en [07.01.00.00.Problema2Cuerpos.Motivacion](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb)
#    - [Figura 7.73](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb#fig:sistemas_jerarquicos). Tipos de sistemas jerarquicos de N cuerpos.. <b>{fig:sistemas_jerarquicos}</b>
# - Figuras en [07.02.00.00.Problema2Cuerpos.ProblemaRelativo](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb)
#    - [Figura 7.74](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:problema_dos_cuerpos). Configuración del problema de los dos cuerpos.. <b>{fig:problema_dos_cuerpos}</b>
#    - [Figura 7.75](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:problema_dos_cuerpos). El problema de los dos cuerpos puede reducirse al movimiento de su vector relativo $. <b>{fig:problema_dos_cuerpos}</b>
#    - [Figura 7.76](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:laplace). Izquierda: pintura de Pierre-Simon Laplace de James Posselwhite. Derecha: portada del Tomo I del Tratado de Mecánica Celeste de Laplace, el libro más importante en el área publicado después de los *Principia* (foto Colección *Heralds of Science from the Burndy Library*.). <b>{fig:laplace}</b>
#    - [Figura 7.77](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:doscuerpos_trayectorias). Trayectorias del vector relativo (arriba) y de las partículas individuales (abajo). Las trayectorias tienen todas la misma excentricidad.  El foco de la trayectoria del vector relativo es un punto arbitrario en el espacio $. <b>{fig:doscuerpos_trayectorias}</b>
#    - [Figura 7.79](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:hooke_newton). Izquierda: ilustración de Newton adaptada de la correspondencia con Hooke en 1679 y en la que explicaba la trayectoria que seguiría una partícula soltada desde el reposo en un punto A a una cierta altura sobre una Tierra que rota. Para esta trayectoria Newton asumía que la fuerza de gravedad era proporcional a la distancia al centro (que es lo que pasaría dentro de la Tierra sólida.)  Derecha: trayectoría elíptica que seguiría la partícula si toda la masa de la Tierra estuviera concentrada en el punto C y la fuerza variara con el inverso del cuadrado de la distancia.  Esta trayectoria fue sugerida por Robert Hooke e inspiro a Newton a demostrar la primera ley de Kepler usando su teoría de la gravedad.. <b>{fig:hooke_newton}</b>
#    - [Figura 7.80](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#fig:cometa_1680). Pintura del holandés Lieve Verschuier que muestra la apariencia del gran cometa de 1680, llamado también el cometa de Newton.  Crédito: Museo de Rotterdam.. <b>{fig:cometa_1680}</b>
# - Figuras en [07.03.00.00.Problema2Cuerpos.OrbitaEspacio](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb)
#    - [Figura 7.81](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#fig:determinacion_orbita). Construcción geométrica requerida para resolver el problema de la determinación de los elementos orbitales de la trayectoria del vector relativo a partir del vector de estado $. <b>{fig:determinacion_orbita}</b>
#    - [Figura 7.82](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#fig:osculatriz). Ilutración del concepto de órbita osculatriz.  La trayectoria del cuerpo (curva continua) no es una cónica.  Sin embargo por cada punto de la curva (p.e. los puntos P y Q) podemos encontrar una cónica que sea tangente a la curva (curvas rayadas) y que tenga como foco ($F_P$ o $F_Q$) el origen de coordenadas.. <b>{fig:osculatriz}</b>
# - Figuras en [07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb)
#    - [Figura 7.84](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#fig:halley). Halley.. <b>{fig:halley}</b>
#    - [Figura 7.87](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#fig:anomalia_excentrica). Construcción geométrica original de Johannes Kepler para interpretar la anomalía media $M$ o su suplemento $M'. <b>{fig:anomalia_excentrica}</b>
# - Figuras en [07.05.00.00.Problema2Cuerpos.AproximacionJerarquico](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb)
#    - [Figura 7.94](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#fig:tycho_instrumentos). Este grabado de 1598 muestra el gran cuadrante mural de Tycho Brahe en *Uraniburgo*, su observatorio astronómico en la isla Hven en Dinámarca. Con este y otra decena de enormes instrumentos, Tycho realizó por más de 20 años observaciones de gran precisión de planetas, estrellas y cometas, que a la larga revolucionarían, no solo la mecánica celeste, sino también la astronomía en general. Crédito: Royal Library.. <b>{fig:tycho_instrumentos}</b>
# - Figuras en [07.06.00.00.Problema2Cuerpos.Perturbaciones](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb)
#    - [Figura 7.98](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#fig:fuerza_perturbadora). Fuerza perturbadora neta $. <b>{fig:fuerza_perturbadora}</b>
# - Figuras en [07.07.00.00.Problema2Cuerpos.ProblemasSeleccionados](07.07.00.00.Problema2Cuerpos.ProblemasSeleccionados.ipynb)
#    - [Figura 7.103](07.07.00.00.Problema2Cuerpos.ProblemasSeleccionados.ipynb#fig:prob:orbita_satelite). Rrepresentación esquemática de la trayectoria elíptica de un satélite.. <b>{fig:prob:orbita_satelite}</b>
# - Figuras en [08.01.00.00.Problema3Cuerpos.CRTBP](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb)
#    - [Figura 8.105](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#fig:crtbp_configuracion). Representación esquemática de la configuración del problema circular restringido de los tres cuerpos.  Todas las cantidades están expresadas en el sistema de unidades canónicas en el que $a=1$ (distancia entre las partículas más masivas) y $. <b>{fig:crtbp_configuracion}</b>
# - Figuras en [08.03.00.00.Problema3Cuerpos.RegionesExclusion](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb)
#    - [Figura 8.114](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#fig:regiones_exclusion_crtbp). Representación esquemática de las regiones de exclusión (área sombreada) en el CRTBP.. <b>{fig:regiones_exclusion_crtbp}</b>
#    - [Figura 8.116](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#fig:definicion_colineales_crtbp). Representación esquemática de la definición de los puntos colineales $L_1$, $L_2$ y $L_3$ en el CRTBP al cambiar el valor de la constante de Jacobi $C_J$.  Los valores críticos de la constante son aproximados y corresponden al caso de un sistema con $. <b>{fig:definicion_colineales_crtbp}</b>
# - Figuras en [08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb)
#    - [Figura 8.121](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#fig:reposo_crtbp). Ilustración esquemática de lo que significa que una partícula de prueba este en equilibrio en el sistema rotante del CRTBP.  Cuando una partícula tiene velocidad cero y esta en uno de los puntos de equilibrio del sistema, la partícula permanecerá en reposo allí.  Sin embargo en el sistema inercial, en realidad, la partícula se mueve siguiendo una trayectoria circular con la misma velocidad angular relativa de las partículas masivas, manteniendo respecto a ella la misma distancia.  Equilibrio en el CRTBP no significa reposo en el sistema de referencia inercial.. <b>{fig:reposo_crtbp}</b>
#    - [Figura 8.122](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#fig:puntos_equilibrio_crtbp). Ubicación esquemática de los puntos de equilibrio de Lagrange: puntos colineales $L_1$, $L_2$ y $L_3$ y puntos triangulares $L_4$ y $L_5$.  Para los puntos colineales se han indicado las distancias $R_{L1}$, $R_{L2}$ y $R_{L3}$ de cada uno a un punto de referencia vecino: la segunda partícula en el caso de $L_1$ y $L_2$ o el lado opuesto de una circunferencia imaginaria centrada en la partícula más masiva y con radio unitario (círcunferencia rayada). Es importante entender que la circunferencia imaginaria representada aquí no es en general la trayectoria de la partícula 2 que debería estar centrada en el origen (centro de masa) y solo coincide con ella en el caso en que $. <b>{fig:puntos_equilibrio_crtbp}</b>
# - Figuras en [08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb)
#    - [Figura 8.126](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb#fig:xray_binary). Representación artística de la transferencia de masa desde una estrella que ha llenado su lóbulo de Roche (a la derecha) tras alcanzar un estadío evolutivo tardío y un objeto compacto (compañera binaria) alrededor del cual se forma un disco de acreción (disco azul a la izquierda).  Este tipo de sistemas puede emitir abundante rayos X lo que permite que la presencia del compañero invisible sea detectadas.. <b>{fig:xray_binary}</b>
#    - [Figura 8.127](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb#fig:pan). Fotografía de la luna de Saturno *Pan* tomada por la sonda Cassini.  Pan es una pequeña luna irregular con un *cinturón* de polvo en su ecuador, que reside entre las partículas de los anillos de Saturno. Crédito: NASA.. <b>{fig:pan}</b>
# - Figuras en [09.00.00.00.FormalismoLagrangiano.Motivacion](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb)
#    - [Figura 9.141](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#fig:principio_trabajos_virtuales). Arriba: una barra de peso $W$ (conocido) se encuentra apoyada sobre un pivote (triángulo) mientra se aplica sobre ella sendas fuerzas $. <b>{fig:principio_trabajos_virtuales}</b>
#    - [Figura 9.142](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#fig:pendulo_simple_dAlambert). Una partícula puntual de peso $. <b>{fig:pendulo_simple_dAlambert}</b>
# - Figuras en [09.01.00.00.FormalismoLagrangiano.VariablesRestricciones](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb)
#    - [Figura 9.143](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#fig:restriccion_no_holonomica). Un cuerpo desliza por la superficie de un cuenco invertido en presencia de un campo gravitacional uniforme.  En algún punto en su descenso, el cuerpo puede desprenderse de la superficie.. <b>{fig:restriccion_no_holonomica}</b>
#    - [Figura 9.144](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#fig:lagrangiano_pendulo_conico). En el péndulo cónico generalizado, la partícula puede moverse libremente oscilando en y alrededor de la dirección vertical.. <b>{fig:lagrangiano_pendulo_conico}</b>
# - Figuras en [09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb)
#    - [Figura 9.145](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#fig:pendulo_elastico). Representación esquemática del péndulo elástico. Una partícula se suspende del extremo de un resorte y se deja oscilar bajo la acción de un campo gravitacional uniforme. La longitud del resorte cuando no se aplica ninguna fuerza es $L$.  En un momento dado el resorte puede estar estirado una distancia $e$ respecto a la longitud de equilibrio.. <b>{fig:pendulo_elastico}</b>
# - Figuras en [09.05.00.00.FormalismoLagrangiano.Simetrias](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb)
#    - [Figura 9.151](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#fig:emmy_noether). Emmy Noether (1883-1935), considerada como una de las matemáticas más importantes de la historia, descubrió el teorema que lleva su nombre y que juega un papel fundamental en la física contemporánea.  Crédito: Erlangen Konrad Jacobs (1930).. <b>{fig:emmy_noether}</b>
# - Figuras en [09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb)
#    - [Figura 9.154](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#fig:regiones_exclusion_potencial_efectivo). Regiones de exclusión y regiones permitidas en un problema de fuerzas centrales. <b>{fig:regiones_exclusion_potencial_efectivo}</b>
# - Figuras en [09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb)
#    - [Figura 9.160](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#fig:albert_einstein). Albert Einstein durante una conferencia en Viena en 1921, seis años después de resolver uno de los problemas más esquivos de la mecánica celeste, la precesión anómala del perihelio de Mercurio.  Crédito: *National Library of Austria.. <b>{fig:albert_einstein}</b>
# - Figuras en [09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb)
#    - [Figura 9.161](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#fig:prob:tres_masas_aro). Tres masas unidas por barras deslizan por un aro.. <b>{fig:prob:tres_masas_aro}</b>
#    - [Figura 9.162](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#fig:prob:dona_resorte). Un canal con forma de *dona* tiene un cuerpo adentro atado a un resorte.. <b>{fig:prob:dona_resorte}</b>
#    - [Figura 9.163](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#fig:prob:cilindros_contacto). Dos cilindros en contacto.. <b>{fig:prob:cilindros_contacto}</b>
#    - [Figura 9.164](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#fig:prob:masas_resorte). Dos masas unidas por resortes que pueden deslizar.. <b>{fig:prob:masas_resorte}</b>
#    - [Figura 9.165](09.06.00.00.FormalismoLagrangiano.ProblemasSeleccionados.ipynb#fig:prob:pendulo_doble). Péndulo doble.. <b>{fig:prob:pendulo_doble}</b>
# - Figuras en [10.00.00.00.FormalismoHamiltoniano.Motivacion](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb)
#    - [Figura 10.166](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#fig:hamiltoniano_sistema_simple). Sistema mecánico usado para ilustrar la complejidad de las ecuaciones de movimiento en el formalismo Lagrangiano, incluso de sistemas relativamente simples.. <b>{fig:hamiltoniano_sistema_simple}</b>
#    - [Figura 10.167](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#fig:espacio_configuracion_fase). El espacio coordenado o espacio de configuración (panel de la izquierda) es degenerado: por un punto cualquier pasan en principio infinitas trayectorias posibles del sistema dinámico correspondiente.  El espacio de posición-velocidad (o espacio de fase como definiremos más adelante) no es degenerado: por un punto, una vez provistas las fuerzas, pasa una y solo una trayectoria.. <b>{fig:espacio_configuracion_fase}</b>
# - Figuras en [10.02.00.00.FormalismoHamiltoniano.EspacioFase](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb)
#    - [Figura 10.168](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb#fig:espacio_fase_interpretacion). Interpretación de las cantidades relevantes en el formalismo Hamiltoniano y de las ecuaciones canónicas en el espacio de fase.. <b>{fig:espacio_fase_interpretacion}</b>
# - Figuras en [10.02.00.00.FormalismoHamiltoniano.Simetrias](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb)
#    - [Figura 10.171](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#fig:lagrangiano_pendulo_conico). En el péndulo cónico generalizado, la partícula puede moverse libremente oscilando en y alrededor de la dirección vertical.. <b>{fig:lagrangiano_pendulo_conico}</b>
# - Figuras en [10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb)
#    - [Figura 10.173](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#fig:Figure_173). Ilustración del efecto en el espacio de fase y en la descripción de la dinámica de un sistema dinámico de una transformación canónica.  En este caso se ilustra el oscilador armónico simple cuyo espacio de fase es tradicionalmente el de la izquierda, y el mismo sistema después de una transformación canónica convenientemente escogida (panel de la derecha).. <b>{fig:Figure_173}</b>

# %% [markdown]
# ## Índice de ecuaciones
# - Ecuaciones en [04.01.01.00.Fundamentos.Calculo.Vectores](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb)
#     - [Ec. (4.1)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Asuma_tuplas): suma_tuplas. <b>{eq:suma_tuplas}</b>
#     - [Ec. (4.2)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Ak_tupla): k_tupla. <b>{eq:k_tupla}</b>
#     - [Ec. (4.3)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Avectores_en_base): vectores_en_base. <b>{eq:vectores_en_base}</b>
#     - [Ec. (4.4)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Adelta_kroenecker): delta_kroenecker. <b>{eq:delta_kroenecker}</b>
#     - [Ec. (4.5)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Abase_mano_derecha): base_mano_derecha. <b>{eq:base_mano_derecha}</b>
#     - [Ec. (4.6)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Alevi_civita): levi_civita. <b>{eq:levi_civita}</b>
#     - [Ec. (4.7)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz): producto_cruz. <b>{eq:producto_cruz}</b>
#     - [Ec. (4.8)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aproducto_cruz_determinante): producto_cruz_determinante. <b>{eq:producto_cruz_determinante}</b>
#     - [Ec. (4.9)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_escalar): triple_producto_escalar. <b>{eq:triple_producto_escalar}</b>
#     - [Ec. (4.10)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Atriple_producto_vectorial): triple_producto_vectorial. <b>{eq:triple_producto_vectorial}</b>
#     - [Ec. (4.11)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aconjunto_mano_derecha): conjunto_mano_derecha. <b>{eq:conjunto_mano_derecha}</b>
#     - [Ec. (4.12)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Acilindricas_a_cartesianas): cilindricas_a_cartesianas. <b>{eq:cilindricas_a_cartesianas}</b>
#     - [Ec. (4.13)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_cilindricas): unitarios_cilindricas. <b>{eq:unitarios_cilindricas}</b>
#     - [Ec. (4.14)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aesfericas_a_cartesianas): esfericas_a_cartesianas. <b>{eq:esfericas_a_cartesianas}</b>
#     - [Ec. (4.15)](04.01.01.00.Fundamentos.Calculo.Vectores.ipynb#mjx-eqn-eq%3Aunitarios_esfericas): unitarios_esfericas. <b>{eq:unitarios_esfericas}</b>
# - Ecuaciones en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Ec. (4.16)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aderivada_definicion): derivada_definicion. <b>{eq:derivada_definicion}</b>
#     - [Ec. (4.17)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_general): regla_cadena_general. <b>{eq:regla_cadena_general}</b>
#     - [Ec. (4.18)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cartesianas): gradiente_cartesianas. <b>{eq:gradiente_cartesianas}</b>
#     - [Ec. (4.19)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_cilindricas): gradiente_cilindricas. <b>{eq:gradiente_cilindricas}</b>
#     - [Ec. (4.20)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Agradiente_esfericas): gradiente_esfericas. <b>{eq:gradiente_esfericas}</b>
#     - [Ec. (4.21)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Aregla_cadena_multivariables): regla_cadena_multivariables. <b>{eq:regla_cadena_multivariables}</b>
#     - [Ec. (4.22)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#mjx-eqn-eq%3Ateorema_fundamental_calculo): teorema_fundamental_calculo. <b>{eq:teorema_fundamental_calculo}</b>
# - Ecuaciones en [04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb)
#     - [Ec. (4.23)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_antiderivada): ecuacion_diferencial_antiderivada. <b>{eq:ecuacion_diferencial_antiderivada}</b>
#     - [Ec. (4.24)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple): ecuacion_diferencial_simple. <b>{eq:ecuacion_diferencial_simple}</b>
#     - [Ec. (4.25)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_reducida): ecuacion_diferencial_simple_reducida. <b>{eq:ecuacion_diferencial_simple_reducida}</b>
#     - [Ec. (4.26)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuaciones_reducidas): ecuaciones_reducidas. <b>{eq:ecuaciones_reducidas}</b>
#     - [Ec. (4.27)](04.01.03.00.Fundamentos.Calculo.EcuacionesDiferenciales.ipynb#mjx-eqn-eq%3Aecuacion_diferencial_simple_identificacion): ecuacion_diferencial_simple_identificacion. <b>{eq:ecuacion_diferencial_simple_identificacion}</b>
# - Ecuaciones en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Ec. (4.28)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Avariacion): variacion. <b>{eq:variacion}</b>
#     - [Ec. (4.29)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Alongitud_curva): longitud_curva. <b>{eq:longitud_curva}</b>
#     - [Ec. (4.30)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Afuncional_integral): funcional_integral. <b>{eq:funcional_integral}</b>
#     - [Ec. (4.31)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3AdIdepsilon): dIdepsilon. <b>{eq:dIdepsilon}</b>
#     - [Ec. (4.32)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_integral_variaciones): ecuacion_integral_variaciones. <b>{eq:ecuacion_integral_variaciones}</b>
#     - [Ec. (4.33)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#mjx-eqn-eq%3Aecuacion_euler_lagrange): ecuacion_euler_lagrange. <b>{eq:ecuacion_euler_lagrange}</b>
# - Ecuaciones en [04.02.01.00.Fundamentos.Conicas.Geometria](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb)
#     - [Ec. (4.34)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_apside): ecuacion_apside. <b>{eq:ecuacion_apside}</b>
#     - [Ec. (4.35)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon): conica_razon. <b>{eq:conica_razon}</b>
#     - [Ec. (4.36)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aconica_razon_cartesianas): conica_razon_cartesianas. <b>{eq:conica_razon_cartesianas}</b>
#     - [Ec. (4.37)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz): ecuacion_directriz. <b>{eq:ecuacion_directriz}</b>
#     - [Ec. (4.38)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aalpha): alpha. <b>{eq:alpha}</b>
#     - [Ec. (4.39)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aq): q. <b>{eq:q}</b>
#     - [Ec. (4.40)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aecuacion_directriz_trasladada): ecuacion_directriz_trasladada. <b>{eq:ecuacion_directriz_trasladada}</b>
#     - [Ec. (4.41)](04.02.01.00.Fundamentos.Conicas.Geometria.ipynb#mjx-eqn-eq%3Aeta_apolonio): eta_apolonio. <b>{eq:eta_apolonio}</b>
# - Ecuaciones en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Ec. (4.42)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_apside_pe): ecuacion_apside_pe. <b>{eq:ecuacion_apside_pe}</b>
#     - [Ec. (4.43)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Atraslacion_centro): traslacion_centro. <b>{eq:traslacion_centro}</b>
#     - [Ec. (4.44)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemayor): semiejemayor. <b>{eq:semiejemayor}</b>
#     - [Ec. (4.45)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro): ecuacion_centro. <b>{eq:ecuacion_centro}</b>
#     - [Ec. (4.46)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Asemiejemenor): semiejemenor. <b>{eq:semiejemenor}</b>
#     - [Ec. (4.47)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_centro_hiperbola): ecuacion_centro_hiperbola. <b>{eq:ecuacion_centro_hiperbola}</b>
#     - [Ec. (4.48)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Abeta): beta. <b>{eq:beta}</b>
#     - [Ec. (4.49)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Acos_psi): cos_psi. <b>{eq:cos_psi}</b>
#     - [Ec. (4.50)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d): rotacion2d. <b>{eq:rotacion2d}</b>
#     - [Ec. (4.51)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_matricial): rotacion2d_matricial. <b>{eq:rotacion2d_matricial}</b>
#     - [Ec. (4.52)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Amatriz_rotacion2d): matriz_rotacion2d. <b>{eq:matriz_rotacion2d}</b>
#     - [Ec. (4.53)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ainversa_matriz_rotacion): inversa_matriz_rotacion. <b>{eq:inversa_matriz_rotacion}</b>
#     - [Ec. (4.54)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa_matricial): rotacion2d_inversa_matricial. <b>{eq:rotacion2d_inversa_matricial}</b>
#     - [Ec. (4.55)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Arotacion2d_inversa): rotacion2d_inversa. <b>{eq:rotacion2d_inversa}</b>
#     - [Ec. (4.56)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_conica_trasladada_rotada): ecuacion_conica_trasladada_rotada. <b>{eq:ecuacion_conica_trasladada_rotada}</b>
#     - [Ec. (4.57)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general): ecuacion_general. <b>{eq:ecuacion_general}</b>
#     - [Ec. (4.58)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aecuacion_general_coeficientes): ecuacion_general_coeficientes. <b>{eq:ecuacion_general_coeficientes}</b>
#     - [Ec. (4.59)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aeta_ecuacion_general): eta_ecuacion_general. <b>{eq:eta_ecuacion_general}</b>
#     - [Ec. (4.60)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Ateta_ecuacion_general): teta_ecuacion_general. <b>{eq:teta_ecuacion_general}</b>
#     - [Ec. (4.61)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#mjx-eqn-eq%3Aty_ecuacion_general): ty_ecuacion_general. <b>{eq:ty_ecuacion_general}</b>
# - Ecuaciones en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Ec. (4.62)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aecuacion_foco): ecuacion_foco. <b>{eq:ecuacion_foco}</b>
#     - [Ec. (4.63)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_f): conica_parametricas_f. <b>{eq:conica_parametricas_f}</b>
#     - [Ec. (4.64)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_ecuacion_cilindricas): conica_ecuacion_cilindricas. <b>{eq:conica_ecuacion_cilindricas}</b>
#     - [Ec. (4.65)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_parametricas_E): conica_parametricas_E. <b>{eq:conica_parametricas_E}</b>
#     - [Ec. (4.66)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Aconica_anomalia_excentrica): conica_anomalia_excentrica. <b>{eq:conica_anomalia_excentrica}</b>
#     - [Ec. (4.67)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3AfE): fE. <b>{eq:fE}</b>
#     - [Ec. (4.68)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#mjx-eqn-eq%3Ahiperbola_parametrica_F): hiperbola_parametrica_F. <b>{eq:hiperbola_parametrica_F}</b>
# - Ecuaciones en [04.02.04.00.Fundamentos.Conicas.Areas](04.02.04.00.Fundamentos.Conicas.Areas.ipynb)
#     - [Ec. (4.69)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector): area_sector. <b>{eq:area_sector}</b>
#     - [Ec. (4.70)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PFQ): A_PFQ. <b>{eq:A_PFQ}</b>
#     - [Ec. (4.71)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_PQO): A_PQO. <b>{eq:A_PQO}</b>
#     - [Ec. (4.72)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3AA_RQO): A_RQO. <b>{eq:A_RQO}</b>
#     - [Ec. (4.73)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_elipse): area_sector_elipse. <b>{eq:area_sector_elipse}</b>
#     - [Ec. (4.74)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_elipse): area_elipse. <b>{eq:area_elipse}</b>
#     - [Ec. (4.75)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_hiperbola): area_sector_hiperbola. <b>{eq:area_sector_hiperbola}</b>
#     - [Ec. (4.76)](04.02.04.00.Fundamentos.Conicas.Areas.ipynb#mjx-eqn-eq%3Aarea_sector_parabola): area_sector_parabola. <b>{eq:area_sector_parabola}</b>
# - Ecuaciones en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Ec. (4.77)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_R): rotacion3d_observador_R. <b>{eq:rotacion3d_observador_R}</b>
#     - [Ec. (4.78)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_observador_M): rotacion3d_observador_M. <b>{eq:rotacion3d_observador_M}</b>
#     - [Ec. (4.79)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_definicion): matrizM_definicion. <b>{eq:matrizM_definicion}</b>
#     - [Ec. (4.80)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita): matrizM_explicita. <b>{eq:matrizM_explicita}</b>
#     - [Ec. (4.81)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3AmatrizM_explicita_transpuesta): matrizM_explicita_transpuesta. <b>{eq:matrizM_explicita_transpuesta}</b>
#     - [Ec. (4.82)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_R): rotacion3d_natural_R. <b>{eq:rotacion3d_natural_R}</b>
#     - [Ec. (4.83)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Arotacion3d_natural_M): rotacion3d_natural_M. <b>{eq:rotacion3d_natural_M}</b>
#     - [Ec. (4.84)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#mjx-eqn-eq%3Aelementos_estado_f): elementos_estado_f. <b>{eq:elementos_estado_f}</b>
# - Ecuaciones en [05.01.01.00.Mecanica.Cinematica.Cantidades](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb)
#     - [Ec. (5.85)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aa_cilindricas): a_cilindricas. <b>{eq:a_cilindricas}</b>
#     - [Ec. (5.86)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aa_esfericas): a_esfericas. <b>{eq:a_esfericas}</b>
#     - [Ec. (5.87)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Atransformaciones_galileo): transformaciones_galileo. <b>{eq:transformaciones_galileo}</b>
#     - [Ec. (5.88)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aley_adicion_velocidades): ley_adicion_velocidades. <b>{eq:ley_adicion_velocidades}</b>
#     - [Ec. (5.89)](05.01.01.00.Mecanica.Cinematica.Cantidades.ipynb#mjx-eqn-eq%3Aley_adicion_aceleraciones): ley_adicion_aceleraciones. <b>{eq:ley_adicion_aceleraciones}</b>
# - Ecuaciones en [05.01.02.00.Mecanica.Cinematica.SolucionEdM](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb)
#     - [Ec. (5.90)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm): edm. <b>{eq:edm}</b>
#     - [Ec. (5.91)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_primer_orden): edm_primer_orden. <b>{eq:edm_primer_orden}</b>
#     - [Ec. (5.92)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_escalar): edm_escalar. <b>{eq:edm_escalar}</b>
#     - [Ec. (5.93)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_primer_orden_escalar): edm_primer_orden_escalar. <b>{eq:edm_primer_orden_escalar}</b>
#     - [Ec. (5.94)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_estado): edm_estado. <b>{eq:edm_estado}</b>
#     - [Ec. (5.95)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_ejemplo1): edm_ejemplo1. <b>{eq:edm_ejemplo1}</b>
#     - [Ec. (5.96)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aedm_ejemplo1_cuadratura): edm_ejemplo1_cuadratura. <b>{eq:edm_ejemplo1_cuadratura}</b>
#     - [Ec. (5.97)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3AIx_ejemplo1): Ix_ejemplo1. <b>{eq:Ix_ejemplo1}</b>
#     - [Ec. (5.98)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3AIx_ejemplo2): Ix_ejemplo2. <b>{eq:Ix_ejemplo2}</b>
#     - [Ec. (5.99)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Aconstantes_ejemplo1): constantes_ejemplo1. <b>{eq:constantes_ejemplo1}</b>
#     - [Ec. (5.100)](05.01.02.00.Mecanica.Cinematica.SolucionEdM.ipynb#mjx-eqn-eq%3Asolucion_ejemplo1): solucion_ejemplo1. <b>{eq:solucion_ejemplo1}</b>
# - Ecuaciones en [05.01.03.00.Mecanica.Cinematica.SolucionNumerica](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb)
#     - [Ec. (5.101)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Aedm_ecuaciones_reducidas): edm_ecuaciones_reducidas. <b>{eq:edm_ecuaciones_reducidas}</b>
#     - [Ec. (5.102)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Avariables_auxiliares_edm): variables_auxiliares_edm. <b>{eq:variables_auxiliares_edm}</b>
#     - [Ec. (5.103)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#mjx-eqn-eq%3Aedm_reducidas_particula): edm_reducidas_particula. <b>{eq:edm_reducidas_particula}</b>
# - Ecuaciones en [05.02.01.00.Mecanica.Dinamica.Postulados](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb)
#     - [Ec. (5.104)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aedm_fuerzas_aplicadas): edm_fuerzas_aplicadas. <b>{eq:edm_fuerzas_aplicadas}</b>
#     - [Ec. (5.105)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aedm_fuerzas_resultantes): edm_fuerzas_resultantes. <b>{eq:edm_fuerzas_resultantes}</b>
#     - [Ec. (5.106)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acirculacion_nula): circulacion_nula. <b>{eq:circulacion_nula}</b>
#     - [Ec. (5.107)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuncion_energia_potencial): funcion_energia_potencial. <b>{eq:funcion_energia_potencial}</b>
#     - [Ec. (5.108)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3AdeltaU_deltaK): deltaU_deltaK. <b>{eq:deltaU_deltaK}</b>
#     - [Ec. (5.109)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_gravitacional): fuerza_gravitacional. <b>{eq:fuerza_gravitacional}</b>
#     - [Ec. (5.110)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_M_m): fuerza_M_m. <b>{eq:fuerza_M_m}</b>
#     - [Ec. (5.111)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acampo_gravitacional): campo_gravitacional. <b>{eq:campo_gravitacional}</b>
#     - [Ec. (5.112)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Afuerza_campo_gravitacional): fuerza_campo_gravitacional. <b>{eq:fuerza_campo_gravitacional}</b>
#     - [Ec. (5.113)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aenergia_potencial_gravitacional): energia_potencial_gravitacional. <b>{eq:energia_potencial_gravitacional}</b>
#     - [Ec. (5.114)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Acampo_gravitacional): campo_gravitacional. <b>{eq:campo_gravitacional}</b>
#     - [Ec. (5.115)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Aenergia_fuerza_campo_gravitacional): energia_fuerza_campo_gravitacional. <b>{eq:energia_fuerza_campo_gravitacional}</b>
#     - [Ec. (5.116)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Apotencial_campo_gravitacional): potencial_campo_gravitacional. <b>{eq:potencial_campo_gravitacional}</b>
#     - [Ec. (5.117)](05.02.01.00.Mecanica.Dinamica.Postulados.ipynb#mjx-eqn-eq%3Arazon_masa_gravitacional_masa_inercial): razon_masa_gravitacional_masa_inercial. <b>{eq:razon_masa_gravitacional_masa_inercial}</b>
# - Ecuaciones en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#     - [Ec. (5.118)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aedm_sistema_particulas): edm_sistema_particulas. <b>{eq:edm_sistema_particulas}</b>
#     - [Ec. (5.119)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Acentro_masa): centro_masa. <b>{eq:centro_masa}</b>
#     - [Ec. (5.120)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aedm_sistema): edm_sistema. <b>{eq:edm_sistema}</b>
#     - [Ec. (5.121)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Adistancia_centro_masa): distancia_centro_masa. <b>{eq:distancia_centro_masa}</b>
#     - [Ec. (5.122)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Atorca_sistema): torca_sistema. <b>{eq:torca_sistema}</b>
#     - [Ec. (5.123)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AdLdt_sistema_torca): dLdt_sistema_torca. <b>{eq:dLdt_sistema_torca}</b>
#     - [Ec. (5.124)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Atorque_sistema): torque_sistema. <b>{eq:torque_sistema}</b>
#     - [Ec. (5.125)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3Aestado_CM): estado_CM. <b>{eq:estado_CM}</b>
#     - [Ec. (5.126)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AL_CM_interno): L_CM_interno. <b>{eq:L_CM_interno}</b>
#     - [Ec. (5.127)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#mjx-eqn-eq%3AK_CM_interno): K_CM_interno. <b>{eq:K_CM_interno}</b>
# - Ecuaciones en [05.03.00.00.Mecanica.SistemasNoInerciales](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb)
#     - [Ec. (5.128)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Atransformaciones_galileo): transformaciones_galileo. <b>{eq:transformaciones_galileo}</b>
#     - [Ec. (5.129)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Atransformaciones_acelerado): transformaciones_acelerado. <b>{eq:transformaciones_acelerado}</b>
#     - [Ec. (5.130)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Av_no_inercial): v_no_inercial. <b>{eq:v_no_inercial}</b>
#     - [Ec. (5.131)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Ap_no_inercial): p_no_inercial. <b>{eq:p_no_inercial}</b>
#     - [Ec. (5.132)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aa_no_inercial): a_no_inercial. <b>{eq:a_no_inercial}</b>
#     - [Ec. (5.133)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AF_no_inercial): F_no_inercial. <b>{eq:F_no_inercial}</b>
#     - [Ec. (5.134)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AF_aplicada_no_inercial): F_aplicada_no_inercial. <b>{eq:F_aplicada_no_inercial}</b>
#     - [Ec. (5.135)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3AA_noinercial): A_noinercial. <b>{eq:A_noinercial}</b>
#     - [Ec. (5.136)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aderivada_vector_rotacion_explicita): derivada_vector_rotacion_explicita. <b>{eq:derivada_vector_rotacion_explicita}</b>
#     - [Ec. (5.137)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aderivada_vector_rotacion): derivada_vector_rotacion. <b>{eq:derivada_vector_rotacion}</b>
#     - [Ec. (5.138)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aomega_times_A): omega_times_A. <b>{eq:omega_times_A}</b>
#     - [Ec. (5.139)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aadicion_velocidades_rotante): adicion_velocidades_rotante. <b>{eq:adicion_velocidades_rotante}</b>
#     - [Ec. (5.140)](05.03.00.00.Mecanica.SistemasNoInerciales.ipynb#mjx-eqn-eq%3Aley_adicion_aceleraciones): ley_adicion_aceleraciones. <b>{eq:ley_adicion_aceleraciones}</b>
# - Ecuaciones en [06.01.00.00.ProblemaNCuerpos.Formulacion](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb)
#     - [Ec. (6.141)](06.01.00.00.ProblemaNCuerpos.Formulacion.ipynb#mjx-eqn-eq%3Ancuerpos_formulacion_ecuaciones): ncuerpos_formulacion_ecuaciones. <b>{eq:ncuerpos_formulacion_ecuaciones}</b>
# - Ecuaciones en [06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb)
#     - [Ec. (6.142)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#mjx-eqn-eq%3Ancuerpos_suma_edm): ncuerpos_suma_edm. <b>{eq:ncuerpos_suma_edm}</b>
#     - [Ec. (6.143)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#mjx-eqn-eq%3Ancuerpos_momento): ncuerpos_momento. <b>{eq:ncuerpos_momento}</b>
#     - [Ec. (6.144)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#mjx-eqn-eq%3Ancuerpos_centro_masa): ncuerpos_centro_masa. <b>{eq:ncuerpos_centro_masa}</b>
#     - [Ec. (6.145)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#mjx-eqn-eq%3Ancuerpos_centro_masa): ncuerpos_centro_masa. <b>{eq:ncuerpos_centro_masa}</b>
#     - [Ec. (6.146)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#mjx-eqn-eq%3Ancuerpos_momento_angular): ncuerpos_momento_angular. <b>{eq:ncuerpos_momento_angular}</b>
# - Ecuaciones en [06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb)
#     - [Ec. (6.147)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3Ancuerpos_edm_potencial_individual): ncuerpos_edm_potencial_individual. <b>{eq:ncuerpos_edm_potencial_individual}</b>
#     - [Ec. (6.148)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3Apotencial_tres_cuerpos): potencial_tres_cuerpos. <b>{eq:potencial_tres_cuerpos}</b>
#     - [Ec. (6.149)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3Ancuerpos_edm_potencial): ncuerpos_edm_potencial. <b>{eq:ncuerpos_edm_potencial}</b>
#     - [Ec. (6.150)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3AU_restringido): U_restringido. <b>{eq:U_restringido}</b>
#     - [Ec. (6.151)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3AU_no_restringido): U_no_restringido. <b>{eq:U_no_restringido}</b>
#     - [Ec. (6.152)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#mjx-eqn-eq%3Ancuerpos_energia): ncuerpos_energia. <b>{eq:ncuerpos_energia}</b>
# - Ecuaciones en [06.02.03.00.ProblemaNCuerpos.SolucionAnalitica.Sintesis](06.02.03.00.ProblemaNCuerpos.SolucionAnalitica.Sintesis.ipynb)
#     - [Ec. (6.153)](06.02.03.00.ProblemaNCuerpos.SolucionAnalitica.Sintesis.ipynb#mjx-eqn-eq%3Ancuerpos_constantes_movimiento): ncuerpos_constantes_movimiento. <b>{eq:ncuerpos_constantes_movimiento}</b>
# - Ecuaciones en [06.03.00.00.ProblemaNCuerpos.TeoremaVirial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb)
#     - [Ec. (6.154)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Amomento_inercia): momento_inercia. <b>{eq:momento_inercia}</b>
#     - [Ec. (6.155)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3AG): G. <b>{eq:G}</b>
#     - [Ec. (6.156)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3AI_G): I_G. <b>{eq:I_G}</b>
#     - [Ec. (6.157)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3AG_acotada): G_acotada. <b>{eq:G_acotada}</b>
#     - [Ec. (6.158)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3AdotG): dotG. <b>{eq:dotG}</b>
#     - [Ec. (6.159)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Aidentidad_lagrange_jacobi): identidad_lagrange_jacobi. <b>{eq:identidad_lagrange_jacobi}</b>
#     - [Ec. (6.160)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Ateorema_virial_UK): teorema_virial_UK. <b>{eq:teorema_virial_UK}</b>
#     - [Ec. (6.161)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Ateorema_virial_EK): teorema_virial_EK. <b>{eq:teorema_virial_EK}</b>
#     - [Ec. (6.162)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Ateorema_virial_canonico): teorema_virial_canonico. <b>{eq:teorema_virial_canonico}</b>
#     - [Ec. (6.163)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#mjx-eqn-eq%3Avirial_v_dispersion): virial_v_dispersion. <b>{eq:virial_v_dispersion}</b>
# - Ecuaciones en [06.03.00.00.ProblemaNCuerpos.SolucionNumerica](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb)
#     - [Ec. (6.164)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#mjx-eqn-eq%3Adefinicion_unidades_canonicas): definicion_unidades_canonicas. <b>{eq:definicion_unidades_canonicas}</b>
#     - [Ec. (6.165)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#mjx-eqn-eq%3Ancuerpos_numerico_ecuaciones): ncuerpos_numerico_ecuaciones. <b>{eq:ncuerpos_numerico_ecuaciones}</b>
#     - [Ec. (6.166)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#mjx-eqn-eq%3Anumerico_variables_auxiliares): numerico_variables_auxiliares. <b>{eq:numerico_variables_auxiliares}</b>
#     - [Ec. (6.167)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#mjx-eqn-eq%3Adefinicion_rij): definicion_rij. <b>{eq:definicion_rij}</b>
#     - [Ec. (6.168)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#mjx-eqn-eq%3Ancuerpos_edmr): ncuerpos_edmr. <b>{eq:ncuerpos_edmr}</b>
# - Ecuaciones en [07.02.00.00.Problema2Cuerpos.ProblemaRelativo](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb)
#     - [Ec. (7.169)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aedm_doscuerpos): edm_doscuerpos. <b>{eq:edm_doscuerpos}</b>
#     - [Ec. (7.170)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ar1_r2_r): r1_r2_r. <b>{eq:r1_r2_r}</b>
#     - [Ec. (7.171)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Av1_v2_v): v1_v2_v. <b>{eq:v1_v2_v}</b>
#     - [Ec. (7.172)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aedm_doscuerpos_relativo): edm_doscuerpos_relativo. <b>{eq:edm_doscuerpos_relativo}</b>
#     - [Ec. (7.173)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ah): h. <b>{eq:h}</b>
#     - [Ec. (7.174)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ar): r. <b>{eq:r}</b>
#     - [Ec. (7.175)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Adotr): dotr. <b>{eq:dotr}</b>
#     - [Ec. (7.176)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ah_escalar): h_escalar. <b>{eq:h_escalar}</b>
#     - [Ec. (7.177)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Avelocidad_areal): velocidad_areal. <b>{eq:velocidad_areal}</b>
#     - [Ec. (7.178)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ah_escalar): h_escalar. <b>{eq:h_escalar}</b>
#     - [Ec. (7.179)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Adotq): dotq. <b>{eq:dotq}</b>
#     - [Ec. (7.180)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aepsilon): epsilon. <b>{eq:epsilon}</b>
#     - [Ec. (7.181)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aepsilon_cartesianas): epsilon_cartesianas. <b>{eq:epsilon_cartesianas}</b>
#     - [Ec. (7.182)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aepsilon_cilindricas): epsilon_cilindricas. <b>{eq:epsilon_cilindricas}</b>
#     - [Ec. (7.183)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aedmxh): edmxh. <b>{eq:edmxh}</b>
#     - [Ec. (7.184)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Acuadratura_e): cuadratura_e. <b>{eq:cuadratura_e}</b>
#     - [Ec. (7.185)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ae): e. <b>{eq:e}</b>
#     - [Ec. (7.186)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ae_h_epsilon): e_h_epsilon. <b>{eq:e_h_epsilon}</b>
#     - [Ec. (7.187)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Adoscuerpos_trayectoria): doscuerpos_trayectoria. <b>{eq:doscuerpos_trayectoria}</b>
#     - [Ec. (7.188)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Adoscuerpos_trayectoria_m1): doscuerpos_trayectoria_m1. <b>{eq:doscuerpos_trayectoria_m1}</b>
#     - [Ec. (7.189)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Adoscuerpos_trayectoria_m2): doscuerpos_trayectoria_m2. <b>{eq:doscuerpos_trayectoria_m2}</b>
#     - [Ec. (7.190)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ae_mu_2a): e_mu_2a. <b>{eq:e_mu_2a}</b>
#     - [Ec. (7.191)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Avis_viva): vis_viva. <b>{eq:vis_viva}</b>
#     - [Ec. (7.192)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Afi_conica): fi_conica. <b>{eq:fi_conica}</b>
#     - [Ec. (7.193)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Atetav_conica): tetav_conica. <b>{eq:tetav_conica}</b>
#     - [Ec. (7.194)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Av_hodografo): v_hodografo. <b>{eq:v_hodografo}</b>
#     - [Ec. (7.195)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Ateorema_armonico): teorema_armonico. <b>{eq:teorema_armonico}</b>
#     - [Ec. (7.196)](07.02.00.00.Problema2Cuerpos.ProblemaRelativo.ipynb#mjx-eqn-eq%3Aley_armonica): ley_armonica. <b>{eq:ley_armonica}</b>
# - Ecuaciones en [07.03.00.00.Problema2Cuerpos.OrbitaEspacio](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb)
#     - [Ec. (7.197)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_hvec): det_hvec. <b>{eq:det_hvec}</b>
#     - [Ec. (7.198)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_evec): det_evec. <b>{eq:det_evec}</b>
#     - [Ec. (7.199)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_nvec): det_nvec. <b>{eq:det_nvec}</b>
#     - [Ec. (7.200)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_p): det_p. <b>{eq:det_p}</b>
#     - [Ec. (7.201)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_e): det_e. <b>{eq:det_e}</b>
#     - [Ec. (7.202)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_i): det_i. <b>{eq:det_i}</b>
#     - [Ec. (7.203)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_W): det_W. <b>{eq:det_W}</b>
#     - [Ec. (7.204)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_w): det_w. <b>{eq:det_w}</b>
#     - [Ec. (7.205)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3AW_cuadrante): W_cuadrante. <b>{eq:W_cuadrante}</b>
#     - [Ec. (7.206)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Aw_cuadrante): w_cuadrante. <b>{eq:w_cuadrante}</b>
#     - [Ec. (7.207)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Adet_f): det_f. <b>{eq:det_f}</b>
#     - [Ec. (7.208)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Af_cuadrante): f_cuadrante. <b>{eq:f_cuadrante}</b>
#     - [Ec. (7.209)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Aelementos_dotx): elementos_dotx. <b>{eq:elementos_dotx}</b>
#     - [Ec. (7.210)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Aelementos_doty): elementos_doty. <b>{eq:elementos_doty}</b>
#     - [Ec. (7.211)](07.03.00.00.Problema2Cuerpos.OrbitaEspacio.ipynb#mjx-eqn-eq%3Aelementos_dotz): elementos_dotz. <b>{eq:elementos_dotz}</b>
# - Ecuaciones en [07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb)
#     - [Ec. (7.212)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Aarea_sector_tiempo): area_sector_tiempo. <b>{eq:area_sector_tiempo}</b>
#     - [Ec. (7.213)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Aecuacion_barker): ecuacion_barker. <b>{eq:ecuacion_barker}</b>
#     - [Ec. (7.214)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3AMp): Mp. <b>{eq:Mp}</b>
#     - [Ec. (7.215)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Af_Mp): f_Mp. <b>{eq:f_Mp}</b>
#     - [Ec. (7.216)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Aecuacion_kepler): ecuacion_kepler. <b>{eq:ecuacion_kepler}</b>
#     - [Ec. (7.217)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Aecuacion_kepler_hiperbola): ecuacion_kepler_hiperbola. <b>{eq:ecuacion_kepler_hiperbola}</b>
#     - [Ec. (7.218)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Akepler_generalizada): kepler_generalizada. <b>{eq:kepler_generalizada}</b>
#     - [Ec. (7.219)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Akepler_generalizada_derivada1): kepler_generalizada_derivada1. <b>{eq:kepler_generalizada_derivada1}</b>
#     - [Ec. (7.220)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Akepler_generalizada_derivada2): kepler_generalizada_derivada2. <b>{eq:kepler_generalizada_derivada2}</b>
#     - [Ec. (7.221)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Akepler_generalizada): kepler_generalizada. <b>{eq:kepler_generalizada}</b>
#     - [Ec. (7.222)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#mjx-eqn-eq%3Af_G): f_G. <b>{eq:f_G}</b>
# - Ecuaciones en [07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb)
#     - [Ec. (7.223)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Akepler_kepler): kepler_kepler. <b>{eq:kepler_kepler}</b>
#     - [Ec. (7.224)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Akepler_puntofijo): kepler_puntofijo. <b>{eq:kepler_puntofijo}</b>
#     - [Ec. (7.225)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Akepler_generalizada_derivada1): kepler_generalizada_derivada1. <b>{eq:kepler_generalizada_derivada1}</b>
#     - [Ec. (7.226)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AE_iteracion): E_iteracion. <b>{eq:E_iteracion}</b>
#     - [Ec. (7.227)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AE_e1): E_e1. <b>{eq:E_e1}</b>
#     - [Ec. (7.228)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AE2): E2. <b>{eq:E2}</b>
#     - [Ec. (7.229)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Acos_taylor): cos_taylor. <b>{eq:cos_taylor}</b>
#     - [Ec. (7.230)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Asin_taylor): sin_taylor. <b>{eq:sin_taylor}</b>
#     - [Ec. (7.231)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AE_e2): E_e2. <b>{eq:E_e2}</b>
#     - [Ec. (7.232)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AE_e3): E_e3. <b>{eq:E_e3}</b>
#     - [Ec. (7.233)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Aserie_gM): serie_gM. <b>{eq:serie_gM}</b>
#     - [Ec. (7.234)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AAn): An. <b>{eq:An}</b>
#     - [Ec. (7.235)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AJn_integral): Jn_integral. <b>{eq:Jn_integral}</b>
#     - [Ec. (7.236)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3AJn_serie): Jn_serie. <b>{eq:Jn_serie}</b>
#     - [Ec. (7.237)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#mjx-eqn-eq%3Akepler_bessel): kepler_bessel. <b>{eq:kepler_bessel}</b>
# - Ecuaciones en [07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb)
#     - [Ec. (7.238)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Aparabola_universal): parabola_universal. <b>{eq:parabola_universal}</b>
#     - [Ec. (7.239)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Akepler_universal): kepler_universal. <b>{eq:kepler_universal}</b>
#     - [Ec. (7.240)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Akepler_universal_stumpff): kepler_universal_stumpff. <b>{eq:kepler_universal_stumpff}</b>
#     - [Ec. (7.241)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Ar_fg): r_fg. <b>{eq:r_fg}</b>
#     - [Ec. (7.242)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Av_fg): v_fg. <b>{eq:v_fg}</b>
#     - [Ec. (7.243)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Af_s): f_s. <b>{eq:f_s}</b>
#     - [Ec. (7.244)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Ag_s): g_s. <b>{eq:g_s}</b>
#     - [Ec. (7.245)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Adotf_s): dotf_s. <b>{eq:dotf_s}</b>
#     - [Ec. (7.246)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Adotg_s): dotg_s. <b>{eq:dotg_s}</b>
#     - [Ec. (7.247)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#mjx-eqn-eq%3Akepler_universal_s): kepler_universal_s. <b>{eq:kepler_universal_s}</b>
# - Ecuaciones en [07.06.00.00.Problema2Cuerpos.Perturbaciones](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb)
#     - [Ec. (7.248)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_epsilon_preliminar): dot_epsilon_preliminar. <b>{eq:dot_epsilon_preliminar}</b>
#     - [Ec. (7.249)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adoscuerpos_trayectoria): doscuerpos_trayectoria. <b>{eq:doscuerpos_trayectoria}</b>
#     - [Ec. (7.250)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_epsilon): dot_epsilon. <b>{eq:dot_epsilon}</b>
#     - [Ec. (7.251)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_a): dot_a. <b>{eq:dot_a}</b>
#     - [Ec. (7.252)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_e_preliminar): dot_e_preliminar. <b>{eq:dot_e_preliminar}</b>
#     - [Ec. (7.253)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_e): dot_e. <b>{eq:dot_e}</b>
#     - [Ec. (7.254)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_i): dot_i. <b>{eq:dot_i}</b>
#     - [Ec. (7.255)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_Omega): dot_Omega. <b>{eq:dot_Omega}</b>
#     - [Ec. (7.256)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_omega): dot_omega. <b>{eq:dot_omega}</b>
#     - [Ec. (7.257)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#mjx-eqn-eq%3Adot_f): dot_f. <b>{eq:dot_f}</b>
# - Ecuaciones en [08.01.00.00.Problema3Cuerpos.CRTBP](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb)
#     - [Ec. (8.258)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#mjx-eqn-eq%3Artbp_general): rtbp_general. <b>{eq:rtbp_general}</b>
#     - [Ec. (8.259)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#mjx-eqn-eq%3Artbp): rtbp. <b>{eq:rtbp}</b>
#     - [Ec. (8.260)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#mjx-eqn-eq%3Artbp_r1_r2): rtbp_r1_r2. <b>{eq:rtbp_r1_r2}</b>
#     - [Ec. (8.261)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#mjx-eqn-eq%3Acrtbp): crtbp. <b>{eq:crtbp}</b>
#     - [Ec. (8.262)](08.01.00.00.Problema3Cuerpos.CRTBP.ipynb#mjx-eqn-eq%3Acrtbp_uc): crtbp_uc. <b>{eq:crtbp_uc}</b>
# - Ecuaciones en [08.02.00.00.Problema3Cuerpos.ConstanteJacobi](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb)
#     - [Ec. (8.263)](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#mjx-eqn-eq%3Acuadratura_Jacobi): cuadratura_Jacobi. <b>{eq:cuadratura_Jacobi}</b>
#     - [Ec. (8.264)](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#mjx-eqn-eq%3Aconstante_Jacobi): constante_Jacobi. <b>{eq:constante_Jacobi}</b>
# - Ecuaciones en [08.03.00.00.Problema3Cuerpos.RegionesExclusion](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb)
#     - [Ec. (8.265)](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#mjx-eqn-eq%3Avelocidad_constante_jacobi): velocidad_constante_jacobi. <b>{eq:velocidad_constante_jacobi}</b>
#     - [Ec. (8.266)](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#mjx-eqn-eq%3Aregiones_exclusion_crtbp): regiones_exclusion_crtbp. <b>{eq:regiones_exclusion_crtbp}</b>
#     - [Ec. (8.267)](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#mjx-eqn-eq%3Aregiones_exclusion_crtbp2): regiones_exclusion_crtbp2. <b>{eq:regiones_exclusion_crtbp2}</b>
# - Ecuaciones en [08.04.00.00.Problema3Cuerpos.PotencialModificado](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb)
#     - [Ec. (8.268)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#mjx-eqn-eq%3Acrtbp_edm): crtbp_edm. <b>{eq:crtbp_edm}</b>
#     - [Ec. (8.269)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#mjx-eqn-eq%3Aedm_crtbp_cero_velocidad): edm_crtbp_cero_velocidad. <b>{eq:edm_crtbp_cero_velocidad}</b>
#     - [Ec. (8.270)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#mjx-eqn-eq%3Aedm_crtbp_reposo): edm_crtbp_reposo. <b>{eq:edm_crtbp_reposo}</b>
#     - [Ec. (8.271)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#mjx-eqn-eq%3AVmod_crtbp): Vmod_crtbp. <b>{eq:Vmod_crtbp}</b>
#     - [Ec. (8.272)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#mjx-eqn-eq%3Acrtbp_edm_Vmod): crtbp_edm_Vmod. <b>{eq:crtbp_edm_Vmod}</b>
# - Ecuaciones en [08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb)
#     - [Ec. (8.273)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3AdVmod_dx_cero): dVmod_dx_cero. <b>{eq:dVmod_dx_cero}</b>
#     - [Ec. (8.274)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3Apuntos_colineales_condicion_x): puntos_colineales_condicion_x. <b>{eq:puntos_colineales_condicion_x}</b>
#     - [Ec. (8.275)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3AL1_aprox): L1_aprox. <b>{eq:L1_aprox}</b>
#     - [Ec. (8.276)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3AxL1_aprox): xL1_aprox. <b>{eq:xL1_aprox}</b>
#     - [Ec. (8.277)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3AxL2_aprox): xL2_aprox. <b>{eq:xL2_aprox}</b>
#     - [Ec. (8.278)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#mjx-eqn-eq%3AxL3_aprox): xL3_aprox. <b>{eq:xL3_aprox}</b>
# - Ecuaciones en [08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb)
#     - [Ec. (8.279)](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb#mjx-eqn-eq%3Aradio_Roche): radio_Roche. <b>{eq:radio_Roche}</b>
# - Ecuaciones en [08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb)
#     - [Ec. (8.280)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_CJ): T_CJ. <b>{eq:T_CJ}</b>
#     - [Ec. (8.281)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_rp_r): T_rp_r. <b>{eq:T_rp_r}</b>
#     - [Ec. (8.282)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_vp_v): T_vp_v. <b>{eq:T_vp_v}</b>
#     - [Ec. (8.283)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_CJ_inercial): T_CJ_inercial. <b>{eq:T_CJ_inercial}</b>
#     - [Ec. (8.284)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_uc): T_uc. <b>{eq:T_uc}</b>
#     - [Ec. (8.285)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#mjx-eqn-eq%3AT_uc): T_uc. <b>{eq:T_uc}</b>
# - Ecuaciones en [09.00.00.00.FormalismoLagrangiano.Motivacion](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb)
#     - [Ec. (9.286)](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#mjx-eqn-eq%3Ateorema_dalambert_lagrange): teorema_dalambert_lagrange. <b>{eq:teorema_dalambert_lagrange}</b>
#     - [Ec. (9.287)](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#mjx-eqn-eq%3Adalambert_pendulo_simple): dalambert_pendulo_simple. <b>{eq:dalambert_pendulo_simple}</b>
#     - [Ec. (9.288)](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#mjx-eqn-eq%3Axy_pendulo_simple): xy_pendulo_simple. <b>{eq:xy_pendulo_simple}</b>
#     - [Ec. (9.289)](09.00.00.00.FormalismoLagrangiano.Motivacion.ipynb#mjx-eqn-eq%3Aedm_pendulo_simple): edm_pendulo_simple. <b>{eq:edm_pendulo_simple}</b>
# - Ecuaciones en [09.01.00.00.FormalismoLagrangiano.VariablesRestricciones](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb)
#     - [Ec. (9.290)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Apendulo_restriccion_cuerda): pendulo_restriccion_cuerda. <b>{eq:pendulo_restriccion_cuerda}</b>
#     - [Ec. (9.291)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Arestriccion_holonomica): restriccion_holonomica. <b>{eq:restriccion_holonomica}</b>
#     - [Ec. (9.292)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Aprincipio_dalambert_aplicadas): principio_dalambert_aplicadas. <b>{eq:principio_dalambert_aplicadas}</b>
#     - [Ec. (9.293)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Ageneralizadas_a_coordenadas): generalizadas_a_coordenadas. <b>{eq:generalizadas_a_coordenadas}</b>
#     - [Ec. (9.294)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Acoordenadas_a_generalizadas): coordenadas_a_generalizadas. <b>{eq:coordenadas_a_generalizadas}</b>
#     - [Ec. (9.295)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Adelta_ri_delta_qj): delta_ri_delta_qj. <b>{eq:delta_ri_delta_qj}</b>
#     - [Ec. (9.296)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Avi_qj): vi_qj. <b>{eq:vi_qj}</b>
#     - [Ec. (9.297)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Aintercambio_derivadas): intercambio_derivadas. <b>{eq:intercambio_derivadas}</b>
#     - [Ec. (9.298)](09.01.00.00.FormalismoLagrangiano.VariablesRestricciones.ipynb#mjx-eqn-eq%3Acancelacion_puntos): cancelacion_puntos. <b>{eq:cancelacion_puntos}</b>
# - Ecuaciones en [09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb)
#     - [Ec. (9.299)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Adalambert_termino_inercial): dalambert_termino_inercial. <b>{eq:dalambert_termino_inercial}</b>
#     - [Ec. (9.300)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3AT): T. <b>{eq:T}</b>
#     - [Ec. (9.301)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3AT): T. <b>{eq:T}</b>
#     - [Ec. (9.302)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Adalambert_termino_fuerza): dalambert_termino_fuerza. <b>{eq:dalambert_termino_fuerza}</b>
#     - [Ec. (9.303)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3AQ): Q. <b>{eq:Q}</b>
#     - [Ec. (9.304)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Aecuaciones_lagrange): ecuaciones_lagrange. <b>{eq:ecuaciones_lagrange}</b>
#     - [Ec. (9.305)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Apendulo_elastico_transformacion): pendulo_elastico_transformacion. <b>{eq:pendulo_elastico_transformacion}</b>
#     - [Ec. (9.306)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Apendulo_elastico_ec_q1): pendulo_elastico_ec_q1. <b>{eq:pendulo_elastico_ec_q1}</b>
#     - [Ec. (9.307)](09.02.00.00.FormalismoLagrangiano.EcuacionesLagrange.ipynb#mjx-eqn-eq%3Apendulo_elastico_ec_q2): pendulo_elastico_ec_q2. <b>{eq:pendulo_elastico_ec_q2}</b>
# - Ecuaciones en [09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana](09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana.ipynb)
#     - [Ec. (9.308)](09.03.00.00.FormalismoLagrangiano.FuncionLagrangiana.ipynb#mjx-eqn-eq%3Aecuaciones_euler_lagrange): ecuaciones_euler_lagrange. <b>{eq:ecuaciones_euler_lagrange}</b>
# - Ecuaciones en [09.04.00.00.FormalismoLagrangiano.PrincipioHamilton](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb)
#     - [Ec. (9.309)](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#mjx-eqn-eq%3Afuncional_calculo_variacional): funcional_calculo_variacional. <b>{eq:funcional_calculo_variacional}</b>
#     - [Ec. (9.310)](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#mjx-eqn-eq%3APS_funcion_referencia): PS_funcion_referencia. <b>{eq:PS_funcion_referencia}</b>
# - Ecuaciones en [09.05.00.00.FormalismoLagrangiano.Simetrias](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb)
#     - [Ec. (9.311)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Atransformacion_inversion): transformacion_inversion. <b>{eq:transformacion_inversion}</b>
#     - [Ec. (9.312)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Atransformacion_general): transformacion_general. <b>{eq:transformacion_general}</b>
#     - [Ec. (9.313)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Amomento_conservado): momento_conservado. <b>{eq:momento_conservado}</b>
#     - [Ec. (9.314)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Atransformacion_ciclica): transformacion_ciclica. <b>{eq:transformacion_ciclica}</b>
#     - [Ec. (9.315)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Afuncion_jacobi): funcion_jacobi. <b>{eq:funcion_jacobi}</b>
#     - [Ec. (9.316)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Ah_conservativo): h_conservativo. <b>{eq:h_conservativo}</b>
#     - [Ec. (9.317)](09.05.00.00.FormalismoLagrangiano.Simetrias.ipynb#mjx-eqn-eq%3Aenergia_cinetica_variables_generalizadas): energia_cinetica_variables_generalizadas. <b>{eq:energia_cinetica_variables_generalizadas}</b>
# - Ecuaciones en [09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb)
#     - [Ec. (9.318)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano_ncuerpos): lagrangiano_ncuerpos. <b>{eq:lagrangiano_ncuerpos}</b>
#     - [Ec. (9.319)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano_doscuerpos_general): lagrangiano_doscuerpos_general. <b>{eq:lagrangiano_doscuerpos_general}</b>
#     - [Ec. (9.320)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano_doscuerpos_relativo): lagrangiano_doscuerpos_relativo. <b>{eq:lagrangiano_doscuerpos_relativo}</b>
#     - [Ec. (9.321)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano_doscuerpos): lagrangiano_doscuerpos. <b>{eq:lagrangiano_doscuerpos}</b>
#     - [Ec. (9.322)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano2B_general): lagrangiano2B_general. <b>{eq:lagrangiano2B_general}</b>
#     - [Ec. (9.323)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Alagrangiano_doscuerpos_reducido): lagrangiano_doscuerpos_reducido. <b>{eq:lagrangiano_doscuerpos_reducido}</b>
#     - [Ec. (9.324)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.ProblemaNCuerpos.ipynb#mjx-eqn-eq%3Adoscuerpos_edm_angular): doscuerpos_edm_angular. <b>{eq:doscuerpos_edm_angular}</b>
# - Ecuaciones en [09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb)
#     - [Ec. (9.325)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#mjx-eqn-eq%3Afcentral_regiones_exclusion): fcentral_regiones_exclusion. <b>{eq:fcentral_regiones_exclusion}</b>
# - Ecuaciones en [09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb)
#     - [Ec. (9.326)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Aedm_variable_angular): edm_variable_angular. <b>{eq:edm_variable_angular}</b>
#     - [Ec. (9.327)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Aedm_variable_radial): edm_variable_radial. <b>{eq:edm_variable_radial}</b>
#     - [Ec. (9.328)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Aforma_orbital): forma_orbital. <b>{eq:forma_orbital}</b>
#     - [Ec. (9.329)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Aforma_orbital_kepler): forma_orbital_kepler. <b>{eq:forma_orbital_kepler}</b>
#     - [Ec. (9.330)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Ageneral_ecuacion_radial): general_ecuacion_radial. <b>{eq:general_ecuacion_radial}</b>
#     - [Ec. (9.331)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#mjx-eqn-eq%3Akepler_diferencial): kepler_diferencial. <b>{eq:kepler_diferencial}</b>
# - Ecuaciones en [09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb)
#     - [Ec. (9.332)](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#mjx-eqn-eq%3Af_modificada): f_modificada. <b>{eq:f_modificada}</b>
#     - [Ec. (9.333)](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#mjx-eqn-eq%3Aforma_orbital_precesion): forma_orbital_precesion. <b>{eq:forma_orbital_precesion}</b>
#     - [Ec. (9.334)](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#mjx-eqn-eq%3Aconica_precesion): conica_precesion. <b>{eq:conica_precesion}</b>
#     - [Ec. (9.335)](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#mjx-eqn-eq%3Aavance_perihelio): avance_perihelio. <b>{eq:avance_perihelio}</b>
# - Ecuaciones en [10.00.00.00.FormalismoHamiltoniano.Motivacion](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb)
#     - [Ec. (10.336)](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#mjx-eqn-eq%3Aeom_mas): eom_mas. <b>{eq:eom_mas}</b>
#     - [Ec. (10.337)](10.00.00.00.FormalismoHamiltoniano.Motivacion.ipynb#mjx-eqn-eq%3Aedm_mas_linearizado): edm_mas_linearizado. <b>{eq:edm_mas_linearizado}</b>
# - Ecuaciones en [10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb)
#     - [Ec. (10.338)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Adotp_Lqp): dotp_Lqp. <b>{eq:dotp_Lqp}</b>
#     - [Ec. (10.339)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Adotp_Lqp): dotp_Lqp. <b>{eq:dotp_Lqp}</b>
#     - [Ec. (10.340)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3AH_L): H_L. <b>{eq:H_L}</b>
#     - [Ec. (10.341)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3AdH_definicion): dH_definicion. <b>{eq:dH_definicion}</b>
#     - [Ec. (10.342)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3AdH_L): dH_L. <b>{eq:dH_L}</b>
#     - [Ec. (10.343)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Adq_H): dq_H. <b>{eq:dq_H}</b>
#     - [Ec. (10.344)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Adp_H): dp_H. <b>{eq:dp_H}</b>
#     - [Ec. (10.345)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Aprincipio_hamilton_modificado): principio_hamilton_modificado. <b>{eq:principio_hamilton_modificado}</b>
#     - [Ec. (10.346)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Aintegrando_hamilton_modificado): integrando_hamilton_modificado. <b>{eq:integrando_hamilton_modificado}</b>
#     - [Ec. (10.347)](10.01.00.00.FormalismoHamiltoniano.EcuacionesCanonicas.ipynb#mjx-eqn-eq%3Afuncionf_hamilton_modificado): funcionf_hamilton_modificado. <b>{eq:funcionf_hamilton_modificado}</b>
# - Ecuaciones en [10.02.00.00.FormalismoHamiltoniano.EspacioFase](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb)
#     - [Ec. (10.348)](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb#mjx-eqn-eq%3Alagrangiano_pendulo_simple): lagrangiano_pendulo_simple. <b>{eq:lagrangiano_pendulo_simple}</b>
# - Ecuaciones en [10.02.00.00.FormalismoHamiltoniano.Simetrias](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb)
#     - [Ec. (10.349)](10.02.00.00.FormalismoHamiltoniano.Simetrias.ipynb#mjx-eqn-eq%3Aedm_pendulo_conico): edm_pendulo_conico. <b>{eq:edm_pendulo_conico}</b>
# - Ecuaciones en [10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb)
#     - [Ec. (10.350)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdQ_K): dQ_K. <b>{eq:dQ_K}</b>
#     - [Ec. (10.351)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdP_H): dP_H. <b>{eq:dP_H}</b>
#     - [Ec. (10.352)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AQ_transformacion): Q_transformacion. <b>{eq:Q_transformacion}</b>
#     - [Ec. (10.353)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AP_transformacion): P_transformacion. <b>{eq:P_transformacion}</b>
#     - [Ec. (10.354)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AQ_transformacion_restringidas): Q_transformacion_restringidas. <b>{eq:Q_transformacion_restringidas}</b>
#     - [Ec. (10.355)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AP_transformacion_restringidas): P_transformacion_restringidas. <b>{eq:P_transformacion_restringidas}</b>
#     - [Ec. (10.356)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdotQ_K): dotQ_K. <b>{eq:dotQ_K}</b>
#     - [Ec. (10.357)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdotQ_simplectica): dotQ_simplectica. <b>{eq:dotQ_simplectica}</b>
#     - [Ec. (10.358)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdotK_simplectica): dotK_simplectica. <b>{eq:dotK_simplectica}</b>
#     - [Ec. (10.359)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdQdq_simplectica): dQdq_simplectica. <b>{eq:dQdq_simplectica}</b>
#     - [Ec. (10.360)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdQdp_simplectica): dQdp_simplectica. <b>{eq:dQdp_simplectica}</b>
#     - [Ec. (10.361)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdPdq_simplectica): dPdq_simplectica. <b>{eq:dPdq_simplectica}</b>
#     - [Ec. (10.362)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdPdp_simplectica): dPdp_simplectica. <b>{eq:dPdp_simplectica}</b>
#     - [Ec. (10.363)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdXdx): dXdx. <b>{eq:dXdx}</b>
#     - [Ec. (10.364)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AdpdP): dpdP. <b>{eq:dpdP}</b>
#     - [Ec. (10.365)](10.03.00.00.FormalismoHamiltoniano.TransformacionesCanonicas.ipynb#mjx-eqn-eq%3AMAS_hamiltoniano_transformado): MAS_hamiltoniano_transformado. <b>{eq:MAS_hamiltoniano_transformado}</b>
# - Ecuaciones en [10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb)
#     - [Ec. (10.366)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AL_transformacion): L_transformacion. <b>{eq:L_transformacion}</b>
#     - [Ec. (10.367)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AQ_transformacion): Q_transformacion. <b>{eq:Q_transformacion}</b>
#     - [Ec. (10.368)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AP_transformacion_F1): P_transformacion_F1. <b>{eq:P_transformacion_F1}</b>
#     - [Ec. (10.369)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3Ap_transformacion_F1): p_transformacion_F1. <b>{eq:p_transformacion_F1}</b>
#     - [Ec. (10.370)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3Atransformacion_canonica_F1_trivial): transformacion_canonica_F1_trivial. <b>{eq:transformacion_canonica_F1_trivial}</b>
#     - [Ec. (10.371)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3Ahamilton_modificado_original): hamilton_modificado_original. <b>{eq:hamilton_modificado_original}</b>
#     - [Ec. (10.372)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3Ahamilton_modificado_transformacion): hamilton_modificado_transformacion. <b>{eq:hamilton_modificado_transformacion}</b>
#     - [Ec. (10.373)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AL_transformacion): L_transformacion. <b>{eq:L_transformacion}</b>
#     - [Ec. (10.374)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3Acondicion_transformaciones_canonicas): condicion_transformaciones_canonicas. <b>{eq:condicion_transformaciones_canonicas}</b>
#     - [Ec. (10.375)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AK_transformacion_F1): K_transformacion_F1. <b>{eq:K_transformacion_F1}</b>
#     - [Ec. (10.376)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AK_H_qP): K_H_qP. <b>{eq:K_H_qP}</b>
#     - [Ec. (10.377)](10.03.01.00.FormalismoHamiltoniano.TransformacionesCanonicas.FuncionGeneratriz.ipynb#mjx-eqn-eq%3AK_H_dFdt): K_H_dFdt. <b>{eq:K_H_dFdt}</b>
# - Ecuaciones en [10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb)
#     - [Ec. (10.378)](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb#mjx-eqn-eq%3AHJ_general): HJ_general. <b>{eq:HJ_general}</b>
#     - [Ec. (10.379)](10.04.00.00.FormalismoHamiltoniano.HamiltonJacobi.ipynb#mjx-eqn-eq%3AHamiltonJacobi): HamiltonJacobi. <b>{eq:HamiltonJacobi}</b>
# - Ecuaciones en [10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb)
#     - [Ec. (10.380)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb#mjx-eqn-eq%3AHamilton_2B_Laplace): Hamilton_2B_Laplace. <b>{eq:Hamilton_2B_Laplace}</b>
#     - [Ec. (10.381)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb#mjx-eqn-eq%3AdAdt_cilindricas): dAdt_cilindricas. <b>{eq:dAdt_cilindricas}</b>
#     - [Ec. (10.382)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.Problema2Cuerpos.ipynb#mjx-eqn-eq%3AAr_H): Ar_H. <b>{eq:Ar_H}</b>
# - Ecuaciones en [10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb)
#     - [Ec. (10.383)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#mjx-eqn-eq%3AHamilton_2B_Laplace): Hamilton_2B_Laplace. <b>{eq:Hamilton_2B_Laplace}</b>
#     - [Ec. (10.384)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#mjx-eqn-eq%3Asolucion_r_t_2B): solucion_r_t_2B. <b>{eq:solucion_r_t_2B}</b>
#     - [Ec. (10.385)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#mjx-eqn-eq%3Asolucion_teta_r_2B): solucion_teta_r_2B. <b>{eq:solucion_teta_r_2B}</b>
#     - [Ec. (10.386)](10.04.00.00.FormalismoHamiltoniano.MecanicaCeleste.HamiltonJacobi.ipynb#mjx-eqn-eq%3Acambio_variable_rE): cambio_variable_rE. <b>{eq:cambio_variable_rE}</b>
# - Ecuaciones en [11.00.00.00.ApendiceAlgoritmos](11.00.00.00.ApendiceAlgoritmos.ipynb)
#     - [Ec. (11.387)](11.00.00.00.ApendiceAlgoritmos.ipynb#mjx-eqn-eq%3Akepler_fourier): kepler_fourier. <b>{eq:kepler_fourier}</b>

# %% [markdown]
# ## Índice de códigos
# - Código en [03.00.00.00.Introduccion](03.00.00.00.Introduccion.ipynb)
#     - [Código (3.1)](03.00.00.00.Introduccion.ipynb#code:rutina_discriminante): rutina_discriminante. <b>{code:rutina_discriminante}</b>
#     - [Código (3.2)](03.00.00.00.Introduccion.ipynb#code:calcula_discriminante): calcula_discriminante. <b>{code:calcula_discriminante}</b>
#     - [Código (3.3)](03.00.00.00.Introduccion.ipynb#code:plot_sin): plot_sin. <b>{code:plot_sin}</b>
# - Código en [04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb)
#     - [Código (4.4)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:rutina_potencial): rutina_potencial. <b>{code:rutina_potencial}</b>
#     - [Código (4.5)](04.01.02.00.Fundamentos.Calculo.CalculoInfinitesimal.ipynb#code:funcion_lambda): funcion_lambda. <b>{code:funcion_lambda}</b>
# - Código en [04.01.04.00.Fundamentos.Calculo.CalculoVariacional](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb)
#     - [Código (4.6)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:funcional_integral): funcional_integral. <b>{code:funcional_integral}</b>
#     - [Código (4.7)](04.01.04.00.Fundamentos.Calculo.CalculoVariacional.ipynb#code:minimiza_arco): minimiza_arco. <b>{code:minimiza_arco}</b>
# - Código en [04.02.02.00.Fundamentos.Conicas.Algebra](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb)
#     - [Código (4.8)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:spice_rotate): spice_rotate. <b>{code:spice_rotate}</b>
#     - [Código (4.9)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:rota_puntos): rota_puntos. <b>{code:rota_puntos}</b>
#     - [Código (4.10)](04.02.02.00.Fundamentos.Conicas.Algebra.ipynb#code:polinomio_segundo_grado): polinomio_segundo_grado. <b>{code:polinomio_segundo_grado}</b>
# - Código en [04.02.03.00.Fundamentos.Conicas.Anomalias](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb)
#     - [Código (4.11)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:conica_dibujo): conica_dibujo. <b>{code:conica_dibujo}</b>
#     - [Código (4.12)](04.02.03.00.Fundamentos.Conicas.Anomalias.ipynb#code:puntos_conica): puntos_conica. <b>{code:puntos_conica}</b>
# - Código en [04.02.05.00.Fundamentos.Conicas.Rotaciones](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb)
#     - [Código (4.13)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_explicito): calculo_M_explicito. <b>{code:calculo_M_explicito}</b>
#     - [Código (4.14)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:calculo_M_general): calculo_M_general. <b>{code:calculo_M_general}</b>
#     - [Código (4.15)](04.02.05.00.Fundamentos.Conicas.Rotaciones.ipynb#code:conica_de_elementos): conica_de_elementos. <b>{code:conica_de_elementos}</b>
# - Código en [05.01.03.00.Mecanica.Cinematica.SolucionNumerica](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb)
#     - [Código (5.16)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:edm_ejemplo1): edm_ejemplo1. <b>{code:edm_ejemplo1}</b>
#     - [Código (5.17)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:ejemplo1_grafico_solucion): ejemplo1_grafico_solucion. <b>{code:ejemplo1_grafico_solucion}</b>
#     - [Código (5.18)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:compara_numerica_analitica): compara_numerica_analitica. <b>{code:compara_numerica_analitica}</b>
#     - [Código (5.19)](05.01.03.00.Mecanica.Cinematica.SolucionNumerica.ipynb#code:solucion_numerica_ejemplo2): solucion_numerica_ejemplo2. <b>{code:solucion_numerica_ejemplo2}</b>
# - Código en [05.02.02.00.Mecanica.Dinamica.SistemaParticulas](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb)
#     - [Código (5.20)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:random_particles): random_particles. <b>{code:random_particles}</b>
#     - [Código (5.21)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:centro_masa): centro_masa. <b>{code:centro_masa}</b>
#     - [Código (5.22)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:grafico_sistema_ejemplo): grafico_sistema_ejemplo. <b>{code:grafico_sistema_ejemplo}</b>
#     - [Código (5.23)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:L_sistema_ejemplo): L_sistema_ejemplo. <b>{code:L_sistema_ejemplo}</b>
#     - [Código (5.24)](05.02.02.00.Mecanica.Dinamica.SistemaParticulas.ipynb#code:K_sistema_ejemplo): K_sistema_ejemplo. <b>{code:K_sistema_ejemplo}</b>
# - Código en [05.03.01.00.Mecanica.SistemasNoInerciales.Numerico](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb)
#     - [Código (5.25)](05.03.01.00.Mecanica.SistemasNoInerciales.Numerico.ipynb#code:plot_rotating_frame): plot_rotating_frame. <b>{code:plot_rotating_frame}</b>
# - Código en [06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb)
#     - [Código (6.26)](06.02.01.00.ProblemaNCuerpos.SolucionAnalitica.ConstantesMovimiento.ipynb#code:masas_estado_planetas): masas_estado_planetas. <b>{code:masas_estado_planetas}</b>
# - Código en [06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb)
#     - [Código (6.27)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#code:estado_tierra_luna): estado_tierra_luna. <b>{code:estado_tierra_luna}</b>
#     - [Código (6.28)](06.02.02.00.ProblemaNCuerpos.SolucionAnalitica.Energia.ipynb#code:energia_tierra_luna): energia_tierra_luna. <b>{code:energia_tierra_luna}</b>
# - Código en [06.03.00.00.ProblemaNCuerpos.TeoremaVirial](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb)
#     - [Código (6.29)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#code:virial_sistema_solar): virial_sistema_solar. <b>{code:virial_sistema_solar}</b>
#     - [Código (6.30)](06.03.00.00.ProblemaNCuerpos.TeoremaVirial.ipynb#code:masa_coma_cluster): masa_coma_cluster. <b>{code:masa_coma_cluster}</b>
# - Código en [06.03.00.00.ProblemaNCuerpos.SolucionNumerica](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb)
#     - [Código (6.31)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:edm_ncuerpos): edm_ncuerpos. <b>{code:edm_ncuerpos}</b>
#     - [Código (6.32)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:solucion_a_rs_vs): solucion_a_rs_vs. <b>{code:solucion_a_rs_vs}</b>
#     - [Código (6.33)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:sistema_a_Y): sistema_a_Y. <b>{code:sistema_a_Y}</b>
#     - [Código (6.34)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:solucion_a_estado): solucion_a_estado. <b>{code:solucion_a_estado}</b>
#     - [Código (6.35)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:ncuerpos_ejemplo1): ncuerpos_ejemplo1. <b>{code:ncuerpos_ejemplo1}</b>
#     - [Código (6.36)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:plot_ncuerpos_3d): plot_ncuerpos_3d. <b>{code:plot_ncuerpos_3d}</b>
#     - [Código (6.37)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ipynb#code:ncuerpos_animacion): ncuerpos_animacion. <b>{code:ncuerpos_animacion}</b>
# - Código en [06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb)
#     - [Código (6.38)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb#code:ncuerpos_constantes_condiciones_iniciales): ncuerpos_constantes_condiciones_iniciales. <b>{code:ncuerpos_constantes_condiciones_iniciales}</b>
#     - [Código (6.39)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb#code:ncuerpos_ejemplo2): ncuerpos_ejemplo2. <b>{code:ncuerpos_ejemplo2}</b>
#     - [Código (6.40)](06.03.00.00.ProblemaNCuerpos.SolucionNumerica.ConstantesMovimiento.ipynb#code:ncuerpos_solucion): ncuerpos_solucion. <b>{code:ncuerpos_solucion}</b>
# - Código en [07.01.00.00.Problema2Cuerpos.Motivacion](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb)
#     - [Código (7.41)](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb#code:ncuerpos_jerarquico1): ncuerpos_jerarquico1. <b>{code:ncuerpos_jerarquico1}</b>
#     - [Código (7.42)](07.01.00.00.Problema2Cuerpos.Motivacion.ipynb#code:ncuerpos_jerarquico1_CM): ncuerpos_jerarquico1_CM. <b>{code:ncuerpos_jerarquico1_CM}</b>
# - Código en [07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb)
#     - [Código (7.43)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#code:funcion_kepler): funcion_kepler. <b>{code:funcion_kepler}</b>
#     - [Código (7.44)](07.04.01.00.Problema2Cuerpos.SolucionTiempo.EcuacionKepler.ipynb#code:plot_funcion_kepler): plot_funcion_kepler. <b>{code:plot_funcion_kepler}</b>
# - Código en [07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb)
#     - [Código (7.45)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:kepler_kepler): kepler_kepler. <b>{code:kepler_kepler}</b>
#     - [Código (7.46)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:kepler_newton): kepler_newton. <b>{code:kepler_newton}</b>
#     - [Código (7.47)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:precision_seminalitica): precision_seminalitica. <b>{code:precision_seminalitica}</b>
#     - [Código (7.48)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:E_vs_M): E_vs_M. <b>{code:E_vs_M}</b>
#     - [Código (7.49)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:kepler_aproximacion): kepler_aproximacion. <b>{code:kepler_aproximacion}</b>
#     - [Código (7.50)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.AproximacionKepler.ipynb#code:kepler_tiempos): kepler_tiempos. <b>{code:kepler_tiempos}</b>
# - Código en [07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb)
#     - [Código (7.51)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb#code:propaga_estado): propaga_estado. <b>{code:propaga_estado}</b>
#     - [Código (7.52)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb#code:ejemplo_propaga_estado): ejemplo_propaga_estado. <b>{code:ejemplo_propaga_estado}</b>
#     - [Código (7.53)](07.04.02.00.Problema2Cuerpos.SolucionTiempo.Sintesis.ipynb#code:error_teoria): error_teoria. <b>{code:error_teoria}</b>
# - Código en [07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb)
#     - [Código (7.54)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#code:funcion_universal_kepler): funcion_universal_kepler. <b>{code:funcion_universal_kepler}</b>
#     - [Código (7.55)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#code:funcion_universal_kepler_s): funcion_universal_kepler_s. <b>{code:funcion_universal_kepler_s}</b>
#     - [Código (7.56)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#code:propaga_f_g): propaga_f_g. <b>{code:propaga_f_g}</b>
#     - [Código (7.57)](07.04.03.00.Problema2Cuerpos.SolucionTiempo.VariablesUniversales.ipynb#code:ejemplo_propaga_fg): ejemplo_propaga_fg. <b>{code:ejemplo_propaga_fg}</b>
# - Código en [07.05.00.00.Problema2Cuerpos.AproximacionJerarquico](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb)
#     - [Código (7.58)](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#code:prediccion_ss): prediccion_ss. <b>{code:prediccion_ss}</b>
#     - [Código (7.59)](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#code:error_posicion_marte): error_posicion_marte. <b>{code:error_posicion_marte}</b>
#     - [Código (7.60)](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#code:variacion_elementos): variacion_elementos. <b>{code:variacion_elementos}</b>
#     - [Código (7.61)](07.05.00.00.Problema2Cuerpos.AproximacionJerarquico.ipynb#code:variacion_elementos): variacion_elementos. <b>{code:variacion_elementos}</b>
# - Código en [07.06.00.00.Problema2Cuerpos.Perturbaciones](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb)
#     - [Código (7.62)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#code:ejemplo_sistema_perturbado): ejemplo_sistema_perturbado. <b>{code:ejemplo_sistema_perturbado}</b>
#     - [Código (7.63)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#code:ejemplo_sistemaA_perturbado): ejemplo_sistemaA_perturbado. <b>{code:ejemplo_sistemaA_perturbado}</b>
#     - [Código (7.64)](07.06.00.00.Problema2Cuerpos.Perturbaciones.ipynb#code:ejemplo_perturbacion_evolucionelementos): ejemplo_perturbacion_evolucionelementos. <b>{code:ejemplo_perturbacion_evolucionelementos}</b>
# - Código en [08.00.00.00.Problema3Cuerpos.Motivacion](08.00.00.00.Problema3Cuerpos.Motivacion.ipynb)
#     - [Código (8.65)](08.00.00.00.Problema3Cuerpos.Motivacion.ipynb#code:trescuerpos_motivacion): trescuerpos_motivacion. <b>{code:trescuerpos_motivacion}</b>
# - Código en [08.02.00.00.Problema3Cuerpos.ConstanteJacobi](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb)
#     - [Código (8.66)](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#code:constante_jacobi): constante_jacobi. <b>{code:constante_jacobi}</b>
#     - [Código (8.67)](08.02.00.00.Problema3Cuerpos.ConstanteJacobi.ipynb#code:constante_jacobi_sistema_real): constante_jacobi_sistema_real. <b>{code:constante_jacobi_sistema_real}</b>
# - Código en [08.03.00.00.Problema3Cuerpos.RegionesExclusion](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb)
#     - [Código (8.68)](08.03.00.00.Problema3Cuerpos.RegionesExclusion.ipynb#code:limites_regiones_exclusion): limites_regiones_exclusion. <b>{code:limites_regiones_exclusion}</b>
# - Código en [08.04.00.00.Problema3Cuerpos.PotencialModificado](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb)
#     - [Código (8.69)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#code:crtbp_Vmod_3d): crtbp_Vmod_3d. <b>{code:crtbp_Vmod_3d}</b>
#     - [Código (8.70)](08.04.00.00.Problema3Cuerpos.PotencialModificado.ipynb#code:Vmod_contornos): Vmod_contornos. <b>{code:Vmod_contornos}</b>
# - Código en [08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb)
#     - [Código (8.71)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#code:crtbp_puntos_colineales_ecuacion): crtbp_puntos_colineales_ecuacion. <b>{code:crtbp_puntos_colineales_ecuacion}</b>
#     - [Código (8.72)](08.05.00.00.Problema3Cuerpos.PuntosEquilibrioLagrange.ipynb#code:crtbp_colineal_aproximacion): crtbp_colineal_aproximacion. <b>{code:crtbp_colineal_aproximacion}</b>
# - Código en [08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb)
#     - [Código (8.73)](08.06.01.00.Problema3Cuerpos.Aplicaciones.RadioHill.ipynb#code:esfera_hill): esfera_hill. <b>{code:esfera_hill}</b>
# - Código en [08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb)
#     - [Código (8.74)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:orbitas_crtbp): orbitas_crtbp. <b>{code:orbitas_crtbp}</b>
#     - [Código (8.75)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:crtbp_orbita1_L4): crtbp_orbita1_L4. <b>{code:crtbp_orbita1_L4}</b>
#     - [Código (8.76)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:crtbp_orbita2_L4): crtbp_orbita2_L4. <b>{code:crtbp_orbita2_L4}</b>
#     - [Código (8.77)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:crtbp_orbita_L3): crtbp_orbita_L3. <b>{code:crtbp_orbita_L3}</b>
#     - [Código (8.78)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:orbitas_crtbp3d): orbitas_crtbp3d. <b>{code:orbitas_crtbp3d}</b>
#     - [Código (8.79)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:crtbp_orbita_L1): crtbp_orbita_L1. <b>{code:crtbp_orbita_L1}</b>
#     - [Código (8.80)](08.06.02.00.Problema3Cuerpos.Aplicaciones.OrbitasCRTBP.ipynb#code:crtbp_orbita_L2): crtbp_orbita_L2. <b>{code:crtbp_orbita_L2}</b>
# - Código en [08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb)
#     - [Código (8.81)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:T_sistema_ejemplo): T_sistema_ejemplo. <b>{code:T_sistema_ejemplo}</b>
#     - [Código (8.82)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:T_sistema_ejemplo_elementos): T_sistema_ejemplo_elementos. <b>{code:T_sistema_ejemplo_elementos}</b>
#     - [Código (8.83)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:T_CJ_numerico): T_CJ_numerico. <b>{code:T_CJ_numerico}</b>
#     - [Código (8.84)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:NEOs_dispersion): NEOs_dispersion. <b>{code:NEOs_dispersion}</b>
#     - [Código (8.85)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:NEOs_dispersion_limites): NEOs_dispersion_limites. <b>{code:NEOs_dispersion_limites}</b>
#     - [Código (8.86)](08.06.03.00.Problema3Cuerpos.Aplicaciones.ParametroTisserand.ipynb#code:T_cometas_jupiter): T_cometas_jupiter. <b>{code:T_cometas_jupiter}</b>
# - Código en [09.04.00.00.FormalismoLagrangiano.PrincipioHamilton](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb)
#     - [Código (9.87)](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#code:accion_general): accion_general. <b>{code:accion_general}</b>
#     - [Código (9.88)](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#code:S_PS_epsilon): S_PS_epsilon. <b>{code:S_PS_epsilon}</b>
#     - [Código (9.89)](09.04.00.00.FormalismoLagrangiano.PrincipioHamilton.ipynb#code:trayectoria_minima_accion): trayectoria_minima_accion. <b>{code:trayectoria_minima_accion}</b>
# - Código en [09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb)
#     - [Código (9.90)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#code:V_doscuerpos): V_doscuerpos. <b>{code:V_doscuerpos}</b>
#     - [Código (9.91)](09.06.00.00.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.ipynb#code:potencial_efectivo): potencial_efectivo. <b>{code:potencial_efectivo}</b>
# - Código en [09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb)
#     - [Código (9.92)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#code:r_teta_general): r_teta_general. <b>{code:r_teta_general}</b>
#     - [Código (9.93)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#code:coordenado_general): coordenado_general. <b>{code:coordenado_general}</b>
#     - [Código (9.94)](09.06.00.01.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.EcuacionRadial.ipynb#code:V_general): V_general. <b>{code:V_general}</b>
# - Código en [09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb)
#     - [Código (9.95)](09.06.00.02.FormalismoLagrangiano.MecanicaCeleste.Problema2Cuerpos.PrecesionPerihelio.ipynb#code:conica_precesion): conica_precesion. <b>{code:conica_precesion}</b>
# - Código en [10.02.00.00.FormalismoHamiltoniano.EspacioFase](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb)
#     - [Código (10.96)](10.02.00.00.FormalismoHamiltoniano.EspacioFase.ipynb#code:contornos_espacio_fase): contornos_espacio_fase. <b>{code:contornos_espacio_fase}</b>
# - Código en [11.00.00.00.ApendiceAlgoritmos](11.00.00.00.ApendiceAlgoritmos.ipynb)
#     - [Código (11.97)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:estado_a_elementos): estado_a_elementos. <b>{code:estado_a_elementos}</b>
#     - [Código (11.98)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:elementos_a_estado): elementos_a_estado. <b>{code:elementos_a_estado}</b>
#     - [Código (11.99)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:metodo_newton): metodo_newton. <b>{code:metodo_newton}</b>
#     - [Código (11.100)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:metodo_laguerre): metodo_laguerre. <b>{code:metodo_laguerre}</b>
#     - [Código (11.101)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:kepler_fourier): kepler_fourier. <b>{code:kepler_fourier}</b>
#     - [Código (11.102)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:kepler_bessel): kepler_bessel. <b>{code:kepler_bessel}</b>
#     - [Código (11.103)](11.00.00.00.ApendiceAlgoritmos.ipynb#code:serie_stumpff): serie_stumpff. <b>{code:serie_stumpff}</b>
